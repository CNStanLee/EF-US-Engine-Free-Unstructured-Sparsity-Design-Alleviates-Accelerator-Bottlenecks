# %%
import torch.nn.functional as F
from brevitas.nn import QuantConv2d, QuantLinear, QuantReLU, QuantIdentity
from brevitas.quant import Int8WeightPerTensorFixedPoint, Int8ActPerTensorFixedPoint
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from tqdm import tqdm
import os
from torch.utils.data import DataLoader
import torch
import onnx
from finn.util.test import get_test_model_trained
from brevitas.export import export_qonnx
from qonnx.util.cleanup import cleanup as qonnx_cleanup
from qonnx.core.modelwrapper import ModelWrapper
from finn.transformation.qonnx.convert_qonnx_to_finn import ConvertQONNXtoFINN
from qonnx.transformation.infer_shapes import InferShapes
from qonnx.transformation.fold_constants import FoldConstants
from qonnx.transformation.general import GiveReadableTensorNames, GiveUniqueNodeNames, RemoveStaticGraphInputs
from finn.util.basic import make_build_dir
from finn.util.visualization import showInNetron
import os

# %%
! nvidia-smi
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Sat Jun 21 23:19:31 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.144.03             Driver Version: 550.144.03     CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4070 ...    Off |   00000000:01:00.0  On |                  N/A |
# | N/A   62C    P3             31W /   80W |     929MiB /   8188MiB |     59%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# +-----------------------------------------------------------------------------------------+
# Using device: cuda

# %%
# print current working directory
print(f"Current working directory: {os.getcwd()}")
# Out:
# Current working directory: /home/changhong/prj/finn/notebooks

# %%
notebook_name = "/EF-US-Engine-Free-Unstructured-Sparsity-Design-Alleviates-Accelerator-Bottlenecks/casestudy1/LeNet_MNIST_BNN"
finn_root = os.getcwd()
build_dir = finn_root+ notebook_name +"/build"
model_dir = finn_root+ notebook_name +"/model"
data_dir = finn_root+ notebook_name +"/data"

# Create directories if they do not exist
os.makedirs(build_dir, exist_ok=True)
os.makedirs(model_dir, exist_ok=True)
os.makedirs(data_dir, exist_ok=True)
print(f"Data directory: {data_dir}")
print(f"Finn root directory: {finn_root}")
print(f"Build directory: {build_dir}")
print(f"Model directory: {model_dir}")
# Out:
# Data directory: /home/changhong/prj/finn/notebooks/EF-US-Engine-Free-Unstructured-Sparsity-Design-Alleviates-Accelerator-Bottlenecks/casestudy1/LeNet_MNIST_BNN/data
# Finn root directory: /home/changhong/prj/finn/notebooks
# Build directory: /home/changhong/prj/finn/notebooks/EF-US-Engine-Free-Unstructured-Sparsity-Design-Alleviates-Accelerator-Bottlenecks/casestudy1/LeNet_MNIST_BNN/build
# Model directory: /home/changhong/prj/finn/notebooks/EF-US-Engine-Free-Unstructured-Sparsity-Design-Alleviates-Accelerator-Bottlenecks/casestudy1/LeNet_MNIST_BNN/model

# %% [markdown]
# # Model define
# This CNV model is modified from brevitas one

# %%
import torch
from torch.nn import BatchNorm1d
from torch.nn import BatchNorm2d
from torch.nn import MaxPool2d, AvgPool2d
from torch.nn import Module
from torch.nn import ModuleList

from brevitas.core.restrict_val import RestrictValueType
from brevitas.nn import QuantConv2d
from brevitas.nn import QuantIdentity
from brevitas.nn import QuantLinear

from brevitas_examples.bnn_pynq.models.common import CommonActQuant
from brevitas_examples.bnn_pynq.models.common import CommonWeightQuant
from brevitas_examples.bnn_pynq.models.tensor_norm import TensorNorm

# %% [markdown]
# # Build a standard CNV 1W1A

# %%
import configparser

# CNV_OUT_CH_POOL = [(64, False), (64, True), (128, False), (128, True), (256, False), (256, False)]
# INTERMEDIATE_FC_FEATURES = [(256, 512), (512, 512)]
# LAST_FC_IN_FEATURES = 512
# LAST_FC_PER_OUT_CH_SCALING = False
# POOL_SIZE = 2
# KERNEL_SIZE = 3

# LeNet-5
CNV_OUT_CH_POOL = [(6, True), (16, True), (120, False)]  
INTERMEDIATE_FC_FEATURES = [(120, 84)]  
LAST_FC_IN_FEATURES = 84 
LAST_FC_PER_OUT_CH_SCALING = False
POOL_SIZE = 2  
KERNEL_SIZE = 5  

model_name = '2c3f1w2a_mnist'

class CNV(Module):

    def __init__(self, num_classes, weight_bit_width, act_bit_width, in_bit_width, in_ch):
        super(CNV, self).__init__()

        self.conv_features = ModuleList()
        self.linear_features = ModuleList()

        self.conv_features.append(QuantIdentity( # for Q1.7 input format
            act_quant=CommonActQuant,
            bit_width=in_bit_width,
            min_val=- 1.0,
            max_val=1.0 - 2.0 ** (-7),
            narrow_range=False,
            restrict_scaling_type=RestrictValueType.POWER_OF_TWO))

        for out_ch, is_pool_enabled in CNV_OUT_CH_POOL:
            self.conv_features.append(
                QuantConv2d(
                    kernel_size=KERNEL_SIZE,
                    in_channels=in_ch,
                    out_channels=out_ch,
                    bias=False,
                    weight_quant=CommonWeightQuant,
                    weight_bit_width=weight_bit_width))
            in_ch = out_ch
            self.conv_features.append(BatchNorm2d(in_ch, eps=1e-4))
            self.conv_features.append(
                QuantIdentity(act_quant=CommonActQuant, bit_width=act_bit_width))
            if is_pool_enabled:
                #self.conv_features.append(MaxPool2d(kernel_size=2))
                self.conv_features.append(AvgPool2d(kernel_size=2))

        for in_features, out_features in INTERMEDIATE_FC_FEATURES:
            self.linear_features.append(
                QuantLinear(
                    in_features=in_features,
                    out_features=out_features,
                    bias=False,
                    weight_quant=CommonWeightQuant,
                    weight_bit_width=weight_bit_width))
            self.linear_features.append(BatchNorm1d(out_features, eps=1e-4))
            self.linear_features.append(
                QuantIdentity(act_quant=CommonActQuant, bit_width=act_bit_width))

        self.linear_features.append(
            QuantLinear(
                in_features=LAST_FC_IN_FEATURES,
                out_features=num_classes,
                bias=False,
                weight_quant=CommonWeightQuant,
                weight_bit_width=weight_bit_width))
        self.linear_features.append(TensorNorm())

        for m in self.modules():
            if isinstance(m, QuantConv2d) or isinstance(m, QuantLinear):
                torch.nn.init.uniform_(m.weight.data, -1, 1)

    def clip_weights(self, min_val, max_val):
        for mod in self.conv_features:
            if isinstance(mod, QuantConv2d):
                mod.weight.data.clamp_(min_val, max_val)
        for mod in self.linear_features:
            if isinstance(mod, QuantLinear):
                mod.weight.data.clamp_(min_val, max_val)

    def forward(self, x):
        x = 2.0 * x - torch.tensor([1.0], device=x.device)
        for mod in self.conv_features:
            x = mod(x)
        x = x.view(x.shape[0], -1)
        for mod in self.linear_features:
            x = mod(x)
        return x 


def cnv(cfg):
    weight_bit_width = cfg.getint('QUANT', 'WEIGHT_BIT_WIDTH')
    act_bit_width = cfg.getint('QUANT', 'ACT_BIT_WIDTH')
    in_bit_width = cfg.getint('QUANT', 'IN_BIT_WIDTH')
    num_classes = cfg.getint('MODEL', 'NUM_CLASSES')
    in_channels = cfg.getint('MODEL', 'IN_CHANNELS')
    net = CNV(
        weight_bit_width=weight_bit_width,
        act_bit_width=act_bit_width,
        in_bit_width=in_bit_width,
        num_classes=num_classes,
        in_ch=in_channels)
    return net

config = configparser.ConfigParser()
config['MODEL'] = {
    'NUM_CLASSES': '10',
    'IN_CHANNELS': '1',
    'DTASET': 'MNIST',
}
config['QUANT'] = {
    'WEIGHT_BIT_WIDTH': '1',
    'ACT_BIT_WIDTH': '2',
    'IN_BIT_WIDTH': '8',
}

model = cnv(config)

# %%
# export the model to ONNX format
onnx_model_path = model_dir + f"/{model_name}.onnx"
# torch.onnx.export(cfg_6c3f_1w1a_minst, 
#                   torch.randn(1, 1, 32, 32), 
#                   onnx_model_path, 
#                   input_names=['input'], 
#                   output_names=['output'], 
#                   dynamic_axes={'input': {0: 'batch_size'}, 'output': {0: 'batch_size'}})


export_qonnx(model, torch.randn(1, 1, 32, 32), onnx_model_path)
qonnx_cleanup(onnx_model_path, out_file=onnx_model_path)

# %%
# Load the MNIST dataset
transform = transforms.Compose([
             transforms.RandomCrop(32, padding=4),
                transforms.RandomHorizontalFlip(),
                transforms.ToTensor()]
)


full_train_set = datasets.MNIST(data_dir, train=True, download=True, transform=transform)
train_size = int(0.8 * len(full_train_set))
val_size = len(full_train_set) - train_size

train_set, val_set = torch.utils.data.random_split(full_train_set, [train_size, val_size])
test_set = datasets.MNIST(data_dir, train=False, download=True, transform=transform)

train_loader = DataLoader(train_set, batch_size=64, shuffle=True)
test_loader = DataLoader(test_set, batch_size=64, shuffle=False)
val_loader = DataLoader(val_set, batch_size=64, shuffle=False)

print("Dataset split complete:")
print(f"Training set: {len(train_set)} samples")
print(f"Validation set: {len(val_set)} samples")
print(f"Test set: {len(test_set)} samples")
# Out:
# Dataset split complete:
# Training set: 48000 samples
# Validation set: 12000 samples
# Test set: 10000 samples

# %%
def train(model, loader, criterion, optimizer, device):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    
    for images, labels in loader:
        images, labels = images.to(device), labels.to(device)
        
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
    
    train_loss = running_loss / len(loader)
    train_acc = 100 * correct / total
    return train_loss, train_acc

def validate(model, loader, criterion, device):
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0
    
    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            
            running_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    
    val_loss = running_loss / len(loader)
    val_acc = 100 * correct / total
    return val_loss, val_acc

def test(model, loader, device):
    model.eval()
    correct = 0
    total = 0
    
    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    
    test_acc = 100 * correct / total
    return test_acc

# %%
model = model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)
num_epochs = 1000

# 选择一种学习率调度策略
# 1. 阶梯式下降
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=30, gamma=0.1)

# 2. 指数衰减
# scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.95)

# 3. 余弦退火
# scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=num_epochs)

# 4. 带热重启的余弦退火
# scheduler = optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=50, T_mult=1)

# 5. 根据指标降低学习率（如验证集loss不再下降时）
#scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.1, patience=10, verbose=True)


best_val_acc = 0.0

model_save_path = model_dir + f"/{model_name}.pth"
best_model_save_path = model_dir + f"/best_{model_name}.pth"

for epoch in range(num_epochs):
    train_loss, train_acc = train(model, train_loader, criterion, optimizer, device)
    val_loss, val_acc = validate(model, val_loader, criterion, device)
    
    if hasattr(model, 'clip_weights'):
        model.clip_weights(-1.0, 1.0)

    # 打印当前学习率
    current_lr = optimizer.param_groups[0]['lr']
    
    print(f'Epoch [{epoch+1}/{num_epochs}], '
          f'LR: {current_lr:.6f}, '
          f'Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}%, '
          f'Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.2f}%')
    
    # 根据验证集准确率调整学习率（对于ReduceLROnPlateau）
    scheduler.step(val_acc)  # 如果是其他调度器，直接使用 scheduler.step()
    
    # 保存最佳模型
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), best_model_save_path)

# 测试最佳模型
model.load_state_dict(torch.load(best_model_save_path))
test_acc = test(model, test_loader, device)
print(f'Test Accuracy of the best model on the test images: {test_acc:.2f}%')
#
# Out:
# Epoch [1/1000], LR: 0.010000, Train Loss: 0.6996, Train Acc: 77.42%, Val Loss: 3.7200, Val Acc: 26.52%
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:198: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
# Epoch [2/1000], LR: 0.010000, Train Loss: 0.3687, Train Acc: 88.22%, Val Loss: 0.7185, Val Acc: 77.78%
# Epoch [3/1000], LR: 0.000100, Train Loss: 0.2689, Train Acc: 91.53%, Val Loss: 0.4514, Val Acc: 85.80%
# Epoch [4/1000], LR: 0.000100, Train Loss: 0.2603, Train Acc: 91.70%, Val Loss: 1.9883, Val Acc: 46.40%
# Epoch [5/1000], LR: 0.001000, Train Loss: 0.2573, Train Acc: 91.76%, Val Loss: 0.3651, Val Acc: 88.34%
# Epoch [6/1000], LR: 0.000100, Train Loss: 0.2458, Train Acc: 92.24%, Val Loss: 0.3747, Val Acc: 88.45%
# Epoch [7/1000], LR: 0.000100, Train Loss: 0.2432, Train Acc: 92.31%, Val Loss: 0.2335, Val Acc: 92.24%
# Epoch [8/1000], LR: 0.000010, Train Loss: 0.2328, Train Acc: 92.55%, Val Loss: 0.2896, Val Acc: 90.96%
# Epoch [9/1000], LR: 0.000010, Train Loss: 0.2358, Train Acc: 92.49%, Val Loss: 0.8368, Val Acc: 73.88%
# Epoch [10/1000], LR: 0.000100, Train Loss: 0.2417, Train Acc: 92.33%, Val Loss: 0.2486, Val Acc: 92.21%
# Epoch [11/1000], LR: 0.000010, Train Loss: 0.2291, Train Acc: 92.73%, Val Loss: 0.2952, Val Acc: 90.97%
# Epoch [12/1000], LR: 0.000010, Train Loss: 0.2317, Train Acc: 92.62%, Val Loss: 0.2293, Val Acc: 92.95%
# Epoch [13/1000], LR: 0.000010, Train Loss: 0.2349, Train Acc: 92.49%, Val Loss: 0.2510, Val Acc: 92.23%
# Epoch [14/1000], LR: 0.000010, Train Loss: 0.2342, Train Acc: 92.61%, Val Loss: 0.4055, Val Acc: 87.41%
# Epoch [15/1000], LR: 0.000100, Train Loss: 0.2399, Train Acc: 92.40%, Val Loss: 0.2530, Val Acc: 92.54%
# Epoch [16/1000], LR: 0.000010, Train Loss: 0.2288, Train Acc: 92.79%, Val Loss: 0.6694, Val Acc: 79.28%
# Epoch [17/1000], LR: 0.000100, Train Loss: 0.2366, Train Acc: 92.68%, Val Loss: 0.3665, Val Acc: 88.48%
# Epoch [18/1000], LR: 0.000100, Train Loss: 0.2364, Train Acc: 92.48%, Val Loss: 0.2793, Val Acc: 91.33%
# Epoch [19/1000], LR: 0.000010, Train Loss: 0.2223, Train Acc: 92.92%, Val Loss: 0.2416, Val Acc: 92.72%
# Epoch [20/1000], LR: 0.000010, Train Loss: 0.2289, Train Acc: 92.73%, Val Loss: 0.2436, Val Acc: 92.28%
# Epoch [21/1000], LR: 0.000010, Train Loss: 0.2323, Train Acc: 92.78%, Val Loss: 3.4234, Val Acc: 35.56%
# Epoch [22/1000], LR: 0.001000, Train Loss: 0.2486, Train Acc: 92.19%, Val Loss: 0.3699, Val Acc: 88.07%
# Epoch [23/1000], LR: 0.000100, Train Loss: 0.2278, Train Acc: 92.85%, Val Loss: 0.3399, Val Acc: 89.50%
# Epoch [24/1000], LR: 0.000100, Train Loss: 0.2273, Train Acc: 92.80%, Val Loss: 0.2961, Val Acc: 90.73%
# Epoch [25/1000], LR: 0.000010, Train Loss: 0.2177, Train Acc: 93.12%, Val Loss: 0.2123, Val Acc: 93.48%
# Epoch [26/1000], LR: 0.000010, Train Loss: 0.2178, Train Acc: 93.21%, Val Loss: 0.2827, Val Acc: 91.24%
# Epoch [27/1000], LR: 0.000010, Train Loss: 0.2230, Train Acc: 92.99%, Val Loss: 0.2824, Val Acc: 91.25%
# Epoch [28/1000], LR: 0.000010, Train Loss: 0.2215, Train Acc: 92.95%, Val Loss: 0.2770, Val Acc: 91.38%
# Epoch [29/1000], LR: 0.000010, Train Loss: 0.2224, Train Acc: 92.95%, Val Loss: 0.2764, Val Acc: 91.42%
# Epoch [30/1000], LR: 0.000010, Train Loss: 0.2228, Train Acc: 93.00%, Val Loss: 0.3379, Val Acc: 89.78%
# Epoch [31/1000], LR: 0.000100, Train Loss: 0.2293, Train Acc: 92.75%, Val Loss: 0.2653, Val Acc: 91.86%
# Epoch [32/1000], LR: 0.000010, Train Loss: 0.2172, Train Acc: 93.08%, Val Loss: 0.2493, Val Acc: 92.18%
# Epoch [33/1000], LR: 0.000010, Train Loss: 0.2195, Train Acc: 92.99%, Val Loss: 0.3385, Val Acc: 89.42%
# Epoch [34/1000], LR: 0.000100, Train Loss: 0.2286, Train Acc: 92.74%, Val Loss: 0.2269, Val Acc: 92.83%
# Epoch [35/1000], LR: 0.000010, Train Loss: 0.2155, Train Acc: 93.28%, Val Loss: 0.9386, Val Acc: 70.77%
# Epoch [36/1000], LR: 0.000100, Train Loss: 0.2293, Train Acc: 92.80%, Val Loss: 0.3394, Val Acc: 89.91%
# Epoch [37/1000], LR: 0.000100, Train Loss: 0.2284, Train Acc: 92.86%, Val Loss: 0.3286, Val Acc: 90.08%
# Epoch [38/1000], LR: 0.000010, Train Loss: 0.2197, Train Acc: 92.99%, Val Loss: 0.1996, Val Acc: 93.84%
# Epoch [39/1000], LR: 0.000010, Train Loss: 0.2217, Train Acc: 93.10%, Val Loss: 0.2444, Val Acc: 92.33%
# Epoch [40/1000], LR: 0.000010, Train Loss: 0.2212, Train Acc: 93.12%, Val Loss: 0.6852, Val Acc: 78.76%
# Epoch [41/1000], LR: 0.000100, Train Loss: 0.2281, Train Acc: 92.78%, Val Loss: 3.6919, Val Acc: 30.57%
# Epoch [42/1000], LR: 0.001000, Train Loss: 0.2441, Train Acc: 92.43%, Val Loss: 0.2968, Val Acc: 90.66%
# Epoch [43/1000], LR: 0.000010, Train Loss: 0.2273, Train Acc: 92.87%, Val Loss: 0.3435, Val Acc: 89.28%
# Epoch [44/1000], LR: 0.000100, Train Loss: 0.2191, Train Acc: 93.11%, Val Loss: 0.2094, Val Acc: 93.62%
# Epoch [45/1000], LR: 0.000010, Train Loss: 0.2131, Train Acc: 93.24%, Val Loss: 1.8073, Val Acc: 48.89%
# Epoch [46/1000], LR: 0.001000, Train Loss: 0.2322, Train Acc: 92.73%, Val Loss: 0.3265, Val Acc: 90.23%
# Epoch [47/1000], LR: 0.000010, Train Loss: 0.2158, Train Acc: 93.34%, Val Loss: 0.1981, Val Acc: 93.91%
# Epoch [48/1000], LR: 0.000010, Train Loss: 0.2088, Train Acc: 93.46%, Val Loss: 0.2182, Val Acc: 93.21%
# Epoch [49/1000], LR: 0.000010, Train Loss: 0.2082, Train Acc: 93.47%, Val Loss: 0.2441, Val Acc: 92.68%
# Epoch [50/1000], LR: 0.000010, Train Loss: 0.2062, Train Acc: 93.45%, Val Loss: 0.3532, Val Acc: 89.40%
# Epoch [51/1000], LR: 0.000100, Train Loss: 0.2087, Train Acc: 93.50%, Val Loss: 0.2230, Val Acc: 93.25%
# Epoch [52/1000], LR: 0.000010, Train Loss: 0.2007, Train Acc: 93.74%, Val Loss: 0.3066, Val Acc: 90.59%
# Epoch [53/1000], LR: 0.000010, Train Loss: 0.2025, Train Acc: 93.70%, Val Loss: 0.2187, Val Acc: 93.31%
# Epoch [54/1000], LR: 0.000010, Train Loss: 0.1986, Train Acc: 93.80%, Val Loss: 0.2116, Val Acc: 93.50%
# Epoch [55/1000], LR: 0.000010, Train Loss: 0.2011, Train Acc: 93.66%, Val Loss: 0.2258, Val Acc: 92.74%
# Epoch [56/1000], LR: 0.000010, Train Loss: 0.2055, Train Acc: 93.48%, Val Loss: 1.5612, Val Acc: 52.65%
# Epoch [57/1000], LR: 0.001000, Train Loss: 0.2259, Train Acc: 92.91%, Val Loss: 0.4658, Val Acc: 85.62%
# Epoch [58/1000], LR: 0.000100, Train Loss: 0.2029, Train Acc: 93.67%, Val Loss: 0.4265, Val Acc: 86.51%
# Epoch [59/1000], LR: 0.000100, Train Loss: 0.2025, Train Acc: 93.71%, Val Loss: 0.2407, Val Acc: 92.82%
# Epoch [60/1000], LR: 0.000010, Train Loss: 0.1965, Train Acc: 93.96%, Val Loss: 0.4285, Val Acc: 86.01%
# Epoch [61/1000], LR: 0.000100, Train Loss: 0.1995, Train Acc: 93.72%, Val Loss: 0.4415, Val Acc: 86.03%
# Epoch [62/1000], LR: 0.000100, Train Loss: 0.1997, Train Acc: 93.70%, Val Loss: 0.2181, Val Acc: 93.24%
# Epoch [63/1000], LR: 0.000010, Train Loss: 0.1944, Train Acc: 93.94%, Val Loss: 0.3108, Val Acc: 89.72%
# Epoch [64/1000], LR: 0.000100, Train Loss: 0.2067, Train Acc: 93.47%, Val Loss: 0.2439, Val Acc: 92.63%
# Epoch [65/1000], LR: 0.000010, Train Loss: 0.2000, Train Acc: 93.80%, Val Loss: 0.4056, Val Acc: 87.72%
# Epoch [66/1000], LR: 0.000100, Train Loss: 0.2048, Train Acc: 93.60%, Val Loss: 0.3511, Val Acc: 89.29%
# Epoch [67/1000], LR: 0.000100, Train Loss: 0.2071, Train Acc: 93.48%, Val Loss: 0.3359, Val Acc: 89.75%
# Epoch [68/1000], LR: 0.000100, Train Loss: 0.1998, Train Acc: 93.60%, Val Loss: 0.2621, Val Acc: 91.66%
# Epoch [69/1000], LR: 0.000010, Train Loss: 0.1915, Train Acc: 93.91%, Val Loss: 0.2093, Val Acc: 93.76%
# Epoch [70/1000], LR: 0.000010, Train Loss: 0.1960, Train Acc: 93.81%, Val Loss: 0.2238, Val Acc: 92.75%
# Epoch [71/1000], LR: 0.000010, Train Loss: 0.2009, Train Acc: 93.65%, Val Loss: 0.3365, Val Acc: 88.83%
# Epoch [72/1000], LR: 0.000100, Train Loss: 0.2027, Train Acc: 93.63%, Val Loss: 0.2653, Val Acc: 91.90%
# Epoch [73/1000], LR: 0.000010, Train Loss: 0.1964, Train Acc: 93.77%, Val Loss: 0.2354, Val Acc: 92.52%
# Epoch [74/1000], LR: 0.000010, Train Loss: 0.1896, Train Acc: 94.10%, Val Loss: 0.2129, Val Acc: 93.38%
# Epoch [75/1000], LR: 0.000010, Train Loss: 0.1953, Train Acc: 93.92%, Val Loss: 0.2689, Val Acc: 91.26%
# Epoch [76/1000], LR: 0.000010, Train Loss: 0.2001, Train Acc: 93.59%, Val Loss: 0.2195, Val Acc: 93.15%
# Epoch [77/1000], LR: 0.000010, Train Loss: 0.2013, Train Acc: 93.71%, Val Loss: 0.1945, Val Acc: 93.75%
# Epoch [78/1000], LR: 0.000010, Train Loss: 0.2015, Train Acc: 93.66%, Val Loss: 0.9843, Val Acc: 70.03%
# Epoch [79/1000], LR: 0.000100, Train Loss: 0.2062, Train Acc: 93.48%, Val Loss: 0.3277, Val Acc: 89.53%
# Epoch [80/1000], LR: 0.000100, Train Loss: 0.2034, Train Acc: 93.63%, Val Loss: 0.2144, Val Acc: 93.23%
# Epoch [81/1000], LR: 0.000010, Train Loss: 0.1946, Train Acc: 93.81%, Val Loss: 0.2271, Val Acc: 92.63%
# Epoch [82/1000], LR: 0.000010, Train Loss: 0.1955, Train Acc: 93.83%, Val Loss: 0.2055, Val Acc: 93.76%
# Epoch [83/1000], LR: 0.000010, Train Loss: 0.1993, Train Acc: 93.75%, Val Loss: 0.3281, Val Acc: 89.64%
# Epoch [84/1000], LR: 0.000100, Train Loss: 0.2086, Train Acc: 93.47%, Val Loss: 0.9047, Val Acc: 72.64%
# Epoch [85/1000], LR: 0.000100, Train Loss: 0.2060, Train Acc: 93.47%, Val Loss: 0.5927, Val Acc: 79.60%
# Epoch [86/1000], LR: 0.000100, Train Loss: 0.2058, Train Acc: 93.55%, Val Loss: 0.4042, Val Acc: 87.73%
# Epoch [87/1000], LR: 0.000100, Train Loss: 0.1988, Train Acc: 93.74%, Val Loss: 0.2712, Val Acc: 91.49%
# Epoch [88/1000], LR: 0.000010, Train Loss: 0.1913, Train Acc: 94.14%, Val Loss: 0.5362, Val Acc: 83.75%
# Epoch [89/1000], LR: 0.000100, Train Loss: 0.2023, Train Acc: 93.72%, Val Loss: 0.3382, Val Acc: 88.24%
# Epoch [90/1000], LR: 0.000100, Train Loss: 0.2061, Train Acc: 93.55%, Val Loss: 0.2192, Val Acc: 93.38%
# Epoch [91/1000], LR: 0.000010, Train Loss: 0.1904, Train Acc: 93.97%, Val Loss: 0.6431, Val Acc: 80.72%
# Epoch [92/1000], LR: 0.000100, Train Loss: 0.2042, Train Acc: 93.57%, Val Loss: 0.2910, Val Acc: 90.92%
# Epoch [93/1000], LR: 0.000010, Train Loss: 0.1935, Train Acc: 93.78%, Val Loss: 0.2376, Val Acc: 92.60%
# Epoch [94/1000], LR: 0.000010, Train Loss: 0.1932, Train Acc: 93.93%, Val Loss: 0.2676, Val Acc: 91.47%
# Epoch [95/1000], LR: 0.000010, Train Loss: 0.1933, Train Acc: 93.92%, Val Loss: 0.2271, Val Acc: 92.74%
# Epoch [96/1000], LR: 0.000010, Train Loss: 0.1972, Train Acc: 93.66%, Val Loss: 0.2223, Val Acc: 93.22%
# Epoch [97/1000], LR: 0.000010, Train Loss: 0.1993, Train Acc: 93.77%, Val Loss: 0.2271, Val Acc: 92.89%
# Epoch [98/1000], LR: 0.000010, Train Loss: 0.1947, Train Acc: 93.92%, Val Loss: 0.2485, Val Acc: 91.88%
# Epoch [99/1000], LR: 0.000010, Train Loss: 0.1922, Train Acc: 93.96%, Val Loss: 0.4725, Val Acc: 84.28%
# Epoch [100/1000], LR: 0.000100, Train Loss: 0.2049, Train Acc: 93.52%, Val Loss: 0.2181, Val Acc: 93.01%
# Epoch [101/1000], LR: 0.000010, Train Loss: 0.1889, Train Acc: 94.01%, Val Loss: 4.7005, Val Acc: 21.25%
# Epoch [102/1000], LR: 0.010000, Train Loss: 0.2697, Train Acc: 91.61%, Val Loss: 0.3567, Val Acc: 88.55%
# Epoch [103/1000], LR: 0.000100, Train Loss: 0.2041, Train Acc: 93.60%, Val Loss: 0.5345, Val Acc: 83.13%
# Epoch [104/1000], LR: 0.000100, Train Loss: 0.1896, Train Acc: 94.14%, Val Loss: 0.6611, Val Acc: 79.97%
# Epoch [105/1000], LR: 0.000100, Train Loss: 0.1894, Train Acc: 94.12%, Val Loss: 1.3295, Val Acc: 57.39%
# Epoch [106/1000], LR: 0.001000, Train Loss: 0.1910, Train Acc: 94.04%, Val Loss: 0.5904, Val Acc: 81.99%
# Epoch [107/1000], LR: 0.000100, Train Loss: 0.1714, Train Acc: 94.60%, Val Loss: 0.1769, Val Acc: 94.69%
# Epoch [108/1000], LR: 0.000010, Train Loss: 0.1673, Train Acc: 94.80%, Val Loss: 0.3074, Val Acc: 89.74%
# Epoch [109/1000], LR: 0.000100, Train Loss: 0.1720, Train Acc: 94.56%, Val Loss: 0.3792, Val Acc: 87.74%
# Epoch [110/1000], LR: 0.000100, Train Loss: 0.1728, Train Acc: 94.49%, Val Loss: 0.2365, Val Acc: 92.13%
# Epoch [111/1000], LR: 0.000010, Train Loss: 0.1684, Train Acc: 94.63%, Val Loss: 0.2560, Val Acc: 92.17%
# Epoch [112/1000], LR: 0.000010, Train Loss: 0.1684, Train Acc: 94.77%, Val Loss: 0.1977, Val Acc: 94.12%
# Epoch [113/1000], LR: 0.000010, Train Loss: 0.1703, Train Acc: 94.60%, Val Loss: 0.2289, Val Acc: 92.71%
# Epoch [114/1000], LR: 0.000010, Train Loss: 0.1689, Train Acc: 94.72%, Val Loss: 0.2655, Val Acc: 91.26%
# Epoch [115/1000], LR: 0.000010, Train Loss: 0.1693, Train Acc: 94.71%, Val Loss: 0.4049, Val Acc: 87.22%
# Epoch [116/1000], LR: 0.000100, Train Loss: 0.1734, Train Acc: 94.56%, Val Loss: 0.1907, Val Acc: 94.03%
# Epoch [117/1000], LR: 0.000010, Train Loss: 0.1650, Train Acc: 94.88%, Val Loss: 0.2881, Val Acc: 90.61%
# Epoch [118/1000], LR: 0.000010, Train Loss: 0.1693, Train Acc: 94.58%, Val Loss: 0.2119, Val Acc: 93.05%
# Epoch [119/1000], LR: 0.000010, Train Loss: 0.1715, Train Acc: 94.62%, Val Loss: 0.2317, Val Acc: 92.62%
# Epoch [120/1000], LR: 0.000010, Train Loss: 0.1708, Train Acc: 94.61%, Val Loss: 0.1999, Val Acc: 93.81%
# Epoch [121/1000], LR: 0.000010, Train Loss: 0.1685, Train Acc: 94.66%, Val Loss: 0.2869, Val Acc: 91.17%
# Epoch [122/1000], LR: 0.000010, Train Loss: 0.1725, Train Acc: 94.59%, Val Loss: 0.2118, Val Acc: 93.47%
# Epoch [123/1000], LR: 0.000010, Train Loss: 0.1710, Train Acc: 94.61%, Val Loss: 0.2142, Val Acc: 93.21%
# Epoch [124/1000], LR: 0.000010, Train Loss: 0.1722, Train Acc: 94.61%, Val Loss: 0.1673, Val Acc: 94.71%
# Epoch [125/1000], LR: 0.000010, Train Loss: 0.1690, Train Acc: 94.57%, Val Loss: 0.2044, Val Acc: 93.58%
# Epoch [126/1000], LR: 0.000010, Train Loss: 0.1740, Train Acc: 94.41%, Val Loss: 0.2141, Val Acc: 92.94%
# Epoch [127/1000], LR: 0.000010, Train Loss: 0.1703, Train Acc: 94.73%, Val Loss: 0.3468, Val Acc: 89.33%
# Epoch [128/1000], LR: 0.000100, Train Loss: 0.1729, Train Acc: 94.54%, Val Loss: 0.2213, Val Acc: 93.24%
# Epoch [129/1000], LR: 0.000010, Train Loss: 0.1734, Train Acc: 94.62%, Val Loss: 0.1899, Val Acc: 94.18%
# Epoch [130/1000], LR: 0.000010, Train Loss: 0.1708, Train Acc: 94.59%, Val Loss: 0.1844, Val Acc: 94.09%
# Epoch [131/1000], LR: 0.000010, Train Loss: 0.1688, Train Acc: 94.70%, Val Loss: 0.1650, Val Acc: 94.94%
# Epoch [132/1000], LR: 0.000010, Train Loss: 0.1659, Train Acc: 94.80%, Val Loss: 0.3563, Val Acc: 88.29%
# Epoch [133/1000], LR: 0.000100, Train Loss: 0.1760, Train Acc: 94.41%, Val Loss: 0.3273, Val Acc: 89.22%
# Epoch [134/1000], LR: 0.000100, Train Loss: 0.1756, Train Acc: 94.47%, Val Loss: 0.4454, Val Acc: 86.46%
# Epoch [135/1000], LR: 0.000100, Train Loss: 0.1721, Train Acc: 94.56%, Val Loss: 0.2842, Val Acc: 90.65%
# Epoch [136/1000], LR: 0.000010, Train Loss: 0.1646, Train Acc: 94.75%, Val Loss: 0.3827, Val Acc: 87.98%
# Epoch [137/1000], LR: 0.000100, Train Loss: 0.1731, Train Acc: 94.56%, Val Loss: 0.2000, Val Acc: 93.48%
# Epoch [138/1000], LR: 0.000010, Train Loss: 0.1677, Train Acc: 94.76%, Val Loss: 0.2335, Val Acc: 92.86%
# Epoch [139/1000], LR: 0.000010, Train Loss: 0.1659, Train Acc: 94.77%, Val Loss: 0.1619, Val Acc: 95.28%
# Epoch [140/1000], LR: 0.000010, Train Loss: 0.1663, Train Acc: 94.74%, Val Loss: 0.3040, Val Acc: 89.92%
# Epoch [141/1000], LR: 0.000100, Train Loss: 0.1721, Train Acc: 94.62%, Val Loss: 0.3485, Val Acc: 88.20%
# Epoch [142/1000], LR: 0.000100, Train Loss: 0.1738, Train Acc: 94.54%, Val Loss: 0.1930, Val Acc: 94.02%
# Epoch [143/1000], LR: 0.000010, Train Loss: 0.1652, Train Acc: 94.77%, Val Loss: 0.1808, Val Acc: 94.64%
# Epoch [144/1000], LR: 0.000010, Train Loss: 0.1671, Train Acc: 94.71%, Val Loss: 0.1872, Val Acc: 94.32%
# Epoch [145/1000], LR: 0.000010, Train Loss: 0.1645, Train Acc: 94.83%, Val Loss: 0.2010, Val Acc: 93.94%
# Epoch [146/1000], LR: 0.000010, Train Loss: 0.1662, Train Acc: 94.70%, Val Loss: 0.1636, Val Acc: 94.87%
# Epoch [147/1000], LR: 0.000010, Train Loss: 0.1686, Train Acc: 94.77%, Val Loss: 0.3672, Val Acc: 88.28%
# Epoch [148/1000], LR: 0.000100, Train Loss: 0.1741, Train Acc: 94.50%, Val Loss: 0.2058, Val Acc: 93.54%
# Epoch [149/1000], LR: 0.000010, Train Loss: 0.1632, Train Acc: 94.89%, Val Loss: 0.3087, Val Acc: 89.62%
# Epoch [150/1000], LR: 0.000100, Train Loss: 0.1762, Train Acc: 94.37%, Val Loss: 0.2179, Val Acc: 93.04%
# Epoch [151/1000], LR: 0.000010, Train Loss: 0.1654, Train Acc: 94.85%, Val Loss: 0.1566, Val Acc: 95.23%
# Epoch [152/1000], LR: 0.000010, Train Loss: 0.1612, Train Acc: 95.00%, Val Loss: 0.2917, Val Acc: 90.52%
# Epoch [153/1000], LR: 0.000010, Train Loss: 0.1655, Train Acc: 94.84%, Val Loss: 0.1714, Val Acc: 94.89%
# Epoch [154/1000], LR: 0.000010, Train Loss: 0.1650, Train Acc: 94.69%, Val Loss: 0.2295, Val Acc: 92.80%
# Epoch [155/1000], LR: 0.000010, Train Loss: 0.1680, Train Acc: 94.74%, Val Loss: 0.2107, Val Acc: 93.44%
# Epoch [156/1000], LR: 0.000010, Train Loss: 0.1639, Train Acc: 94.79%, Val Loss: 0.2030, Val Acc: 93.65%
# Epoch [157/1000], LR: 0.000010, Train Loss: 0.1665, Train Acc: 94.81%, Val Loss: 0.2983, Val Acc: 90.70%
# Epoch [158/1000], LR: 0.000010, Train Loss: 0.1680, Train Acc: 94.67%, Val Loss: 0.2471, Val Acc: 92.52%
# Epoch [159/1000], LR: 0.000010, Train Loss: 0.1679, Train Acc: 94.72%, Val Loss: 0.1653, Val Acc: 95.06%
# Epoch [160/1000], LR: 0.000010, Train Loss: 0.1642, Train Acc: 94.81%, Val Loss: 0.1682, Val Acc: 94.84%
# Epoch [161/1000], LR: 0.000010, Train Loss: 0.1693, Train Acc: 94.56%, Val Loss: 0.1496, Val Acc: 95.32%
# Epoch [162/1000], LR: 0.000010, Train Loss: 0.1703, Train Acc: 94.63%, Val Loss: 0.1760, Val Acc: 94.63%
# Epoch [163/1000], LR: 0.000010, Train Loss: 0.1667, Train Acc: 94.70%, Val Loss: 0.2124, Val Acc: 93.44%
# Epoch [164/1000], LR: 0.000010, Train Loss: 0.1658, Train Acc: 94.81%, Val Loss: 0.3148, Val Acc: 90.21%
# Epoch [165/1000], LR: 0.000010, Train Loss: 0.1655, Train Acc: 94.74%, Val Loss: 0.4237, Val Acc: 86.08%
# Epoch [166/1000], LR: 0.000100, Train Loss: 0.1731, Train Acc: 94.64%, Val Loss: 0.1842, Val Acc: 94.32%
# Epoch [167/1000], LR: 0.000010, Train Loss: 0.1670, Train Acc: 94.73%, Val Loss: 0.1869, Val Acc: 94.55%
# Epoch [168/1000], LR: 0.000010, Train Loss: 0.1618, Train Acc: 94.85%, Val Loss: 0.2094, Val Acc: 93.56%
# Epoch [169/1000], LR: 0.000010, Train Loss: 0.1660, Train Acc: 94.79%, Val Loss: 0.2699, Val Acc: 91.49%
# Epoch [170/1000], LR: 0.000010, Train Loss: 0.1626, Train Acc: 94.81%, Val Loss: 0.2722, Val Acc: 91.37%
# Epoch [171/1000], LR: 0.000010, Train Loss: 0.1635, Train Acc: 94.90%, Val Loss: 0.3291, Val Acc: 89.92%
# Epoch [172/1000], LR: 0.000100, Train Loss: 0.1720, Train Acc: 94.60%, Val Loss: 0.5237, Val Acc: 83.91%
# Epoch [173/1000], LR: 0.000100, Train Loss: 0.1710, Train Acc: 94.59%, Val Loss: 0.4070, Val Acc: 87.28%
# Epoch [174/1000], LR: 0.000100, Train Loss: 0.1708, Train Acc: 94.59%, Val Loss: 0.2046, Val Acc: 93.52%
# Epoch [175/1000], LR: 0.000010, Train Loss: 0.1638, Train Acc: 94.87%, Val Loss: 0.1686, Val Acc: 94.69%
# Epoch [176/1000], LR: 0.000010, Train Loss: 0.1622, Train Acc: 94.94%, Val Loss: 0.6519, Val Acc: 79.91%
# Epoch [177/1000], LR: 0.000100, Train Loss: 0.1718, Train Acc: 94.58%, Val Loss: 0.2313, Val Acc: 92.66%
# Epoch [178/1000], LR: 0.000010, Train Loss: 0.1628, Train Acc: 94.89%, Val Loss: 0.1794, Val Acc: 94.56%
# Epoch [179/1000], LR: 0.000010, Train Loss: 0.1615, Train Acc: 94.92%, Val Loss: 0.1932, Val Acc: 94.08%
# Epoch [180/1000], LR: 0.000010, Train Loss: 0.1614, Train Acc: 94.82%, Val Loss: 0.2403, Val Acc: 92.16%
# Epoch [181/1000], LR: 0.000010, Train Loss: 0.1642, Train Acc: 94.81%, Val Loss: 0.1669, Val Acc: 94.89%
# Epoch [182/1000], LR: 0.000010, Train Loss: 0.1636, Train Acc: 94.92%, Val Loss: 0.1504, Val Acc: 95.18%
# Epoch [183/1000], LR: 0.000010, Train Loss: 0.1666, Train Acc: 94.80%, Val Loss: 0.4639, Val Acc: 85.03%
# Epoch [184/1000], LR: 0.000100, Train Loss: 0.1729, Train Acc: 94.54%, Val Loss: 0.6426, Val Acc: 81.34%
# Epoch [185/1000], LR: 0.000100, Train Loss: 0.1737, Train Acc: 94.54%, Val Loss: 0.1807, Val Acc: 94.23%
# Epoch [186/1000], LR: 0.000010, Train Loss: 0.1632, Train Acc: 94.89%, Val Loss: 0.2338, Val Acc: 92.31%
# Epoch [187/1000], LR: 0.000010, Train Loss: 0.1628, Train Acc: 94.97%, Val Loss: 0.2593, Val Acc: 92.30%
# Epoch [188/1000], LR: 0.000010, Train Loss: 0.1652, Train Acc: 94.91%, Val Loss: 0.2981, Val Acc: 89.95%
# Epoch [189/1000], LR: 0.000100, Train Loss: 0.1710, Train Acc: 94.67%, Val Loss: 0.2908, Val Acc: 91.18%
# Epoch [190/1000], LR: 0.000010, Train Loss: 0.1603, Train Acc: 94.91%, Val Loss: 0.1613, Val Acc: 95.08%
# Epoch [191/1000], LR: 0.000010, Train Loss: 0.1624, Train Acc: 94.91%, Val Loss: 0.2459, Val Acc: 92.19%
# Epoch [192/1000], LR: 0.000010, Train Loss: 0.1646, Train Acc: 94.82%, Val Loss: 0.8336, Val Acc: 76.83%
# Epoch [193/1000], LR: 0.000100, Train Loss: 0.1705, Train Acc: 94.68%, Val Loss: 0.1758, Val Acc: 94.65%
# Epoch [194/1000], LR: 0.000010, Train Loss: 0.1611, Train Acc: 94.91%, Val Loss: 0.2688, Val Acc: 91.59%
# Epoch [195/1000], LR: 0.000010, Train Loss: 0.1569, Train Acc: 94.94%, Val Loss: 0.3049, Val Acc: 90.80%
# Epoch [196/1000], LR: 0.000010, Train Loss: 0.1628, Train Acc: 94.90%, Val Loss: 0.2933, Val Acc: 90.94%
# Epoch [197/1000], LR: 0.000010, Train Loss: 0.1613, Train Acc: 94.93%, Val Loss: 0.1833, Val Acc: 94.31%
# Epoch [198/1000], LR: 0.000010, Train Loss: 0.1587, Train Acc: 95.01%, Val Loss: 0.1761, Val Acc: 94.62%
# Epoch [199/1000], LR: 0.000010, Train Loss: 0.1602, Train Acc: 95.00%, Val Loss: 0.1992, Val Acc: 94.00%
# Epoch [200/1000], LR: 0.000010, Train Loss: 0.1604, Train Acc: 94.93%, Val Loss: 0.1833, Val Acc: 94.28%
# Epoch [201/1000], LR: 0.000010, Train Loss: 0.1619, Train Acc: 94.89%, Val Loss: 0.3161, Val Acc: 89.53%
# Epoch [202/1000], LR: 0.000100, Train Loss: 0.1679, Train Acc: 94.79%, Val Loss: 0.2242, Val Acc: 92.89%
# Epoch [203/1000], LR: 0.000010, Train Loss: 0.1567, Train Acc: 95.06%, Val Loss: 0.2902, Val Acc: 90.70%
# Epoch [204/1000], LR: 0.000010, Train Loss: 0.1629, Train Acc: 94.89%, Val Loss: 0.1869, Val Acc: 94.22%
# Epoch [205/1000], LR: 0.000010, Train Loss: 0.1605, Train Acc: 94.93%, Val Loss: 0.1769, Val Acc: 94.47%
# Epoch [206/1000], LR: 0.000010, Train Loss: 0.1568, Train Acc: 94.99%, Val Loss: 0.2426, Val Acc: 92.20%
# Epoch [207/1000], LR: 0.000010, Train Loss: 0.1572, Train Acc: 95.20%, Val Loss: 0.1536, Val Acc: 95.24%
# Epoch [208/1000], LR: 0.000010, Train Loss: 0.1605, Train Acc: 94.99%, Val Loss: 0.2327, Val Acc: 92.57%
# Epoch [209/1000], LR: 0.000010, Train Loss: 0.1614, Train Acc: 94.88%, Val Loss: 0.3021, Val Acc: 89.46%
# Epoch [210/1000], LR: 0.000100, Train Loss: 0.1644, Train Acc: 94.73%, Val Loss: 0.2258, Val Acc: 93.44%
# Epoch [211/1000], LR: 0.000010, Train Loss: 0.1590, Train Acc: 95.06%, Val Loss: 0.2070, Val Acc: 93.58%
# Epoch [212/1000], LR: 0.000010, Train Loss: 0.1599, Train Acc: 95.04%, Val Loss: 0.2677, Val Acc: 92.06%
# Epoch [213/1000], LR: 0.000010, Train Loss: 0.1618, Train Acc: 94.96%, Val Loss: 0.2715, Val Acc: 91.80%
# Epoch [214/1000], LR: 0.000010, Train Loss: 0.1595, Train Acc: 94.99%, Val Loss: 0.2828, Val Acc: 91.54%
# Epoch [215/1000], LR: 0.000010, Train Loss: 0.1602, Train Acc: 94.90%, Val Loss: 0.1972, Val Acc: 93.72%
# Epoch [216/1000], LR: 0.000010, Train Loss: 0.1594, Train Acc: 94.96%, Val Loss: 0.2066, Val Acc: 93.39%
# Epoch [217/1000], LR: 0.000010, Train Loss: 0.1618, Train Acc: 94.85%, Val Loss: 0.1727, Val Acc: 94.48%
# Epoch [218/1000], LR: 0.000010, Train Loss: 0.1631, Train Acc: 94.79%, Val Loss: 0.1628, Val Acc: 94.91%
# Epoch [219/1000], LR: 0.000010, Train Loss: 0.1596, Train Acc: 94.95%, Val Loss: 0.2328, Val Acc: 92.67%
# Epoch [220/1000], LR: 0.000010, Train Loss: 0.1610, Train Acc: 94.97%, Val Loss: 0.2246, Val Acc: 92.88%
# Epoch [221/1000], LR: 0.000010, Train Loss: 0.1541, Train Acc: 95.10%, Val Loss: 0.2535, Val Acc: 91.42%
# Epoch [222/1000], LR: 0.000010, Train Loss: 0.1615, Train Acc: 94.93%, Val Loss: 0.1870, Val Acc: 93.89%
# Epoch [223/1000], LR: 0.000010, Train Loss: 0.1595, Train Acc: 95.02%, Val Loss: 0.1688, Val Acc: 94.71%
# Epoch [224/1000], LR: 0.000010, Train Loss: 0.1624, Train Acc: 94.89%, Val Loss: 0.1524, Val Acc: 95.20%
# Epoch [225/1000], LR: 0.000010, Train Loss: 0.1620, Train Acc: 94.85%, Val Loss: 0.1524, Val Acc: 95.03%
# Epoch [226/1000], LR: 0.000010, Train Loss: 0.1608, Train Acc: 94.97%, Val Loss: 0.7262, Val Acc: 78.31%
# Epoch [227/1000], LR: 0.000100, Train Loss: 0.1735, Train Acc: 94.52%, Val Loss: 0.3019, Val Acc: 89.95%
# Epoch [228/1000], LR: 0.000100, Train Loss: 0.1672, Train Acc: 94.61%, Val Loss: 0.2285, Val Acc: 93.12%
# Epoch [229/1000], LR: 0.000010, Train Loss: 0.1574, Train Acc: 95.05%, Val Loss: 0.2406, Val Acc: 92.68%
# Epoch [230/1000], LR: 0.000010, Train Loss: 0.1565, Train Acc: 95.04%, Val Loss: 0.1748, Val Acc: 94.42%
# Epoch [231/1000], LR: 0.000010, Train Loss: 0.1587, Train Acc: 95.08%, Val Loss: 0.1906, Val Acc: 94.22%
# Epoch [232/1000], LR: 0.000010, Train Loss: 0.1576, Train Acc: 94.97%, Val Loss: 0.1590, Val Acc: 94.97%
# Epoch [233/1000], LR: 0.000010, Train Loss: 0.1605, Train Acc: 95.00%, Val Loss: 0.1714, Val Acc: 94.56%
# Epoch [234/1000], LR: 0.000010, Train Loss: 0.1585, Train Acc: 95.15%, Val Loss: 0.1444, Val Acc: 95.62%
# Epoch [235/1000], LR: 0.000010, Train Loss: 0.1621, Train Acc: 94.88%, Val Loss: 0.1756, Val Acc: 94.43%
# Epoch [236/1000], LR: 0.000010, Train Loss: 0.1606, Train Acc: 94.92%, Val Loss: 0.2981, Val Acc: 90.21%
# Epoch [237/1000], LR: 0.000010, Train Loss: 0.1602, Train Acc: 94.95%, Val Loss: 1.3478, Val Acc: 61.01%
# Epoch [238/1000], LR: 0.000100, Train Loss: 0.1735, Train Acc: 94.57%, Val Loss: 0.2767, Val Acc: 91.58%
# Epoch [239/1000], LR: 0.000010, Train Loss: 0.1622, Train Acc: 94.86%, Val Loss: 0.2590, Val Acc: 92.33%
# Epoch [240/1000], LR: 0.000010, Train Loss: 0.1560, Train Acc: 95.02%, Val Loss: 0.2933, Val Acc: 91.08%
# Epoch [241/1000], LR: 0.000010, Train Loss: 0.1569, Train Acc: 95.09%, Val Loss: 0.6208, Val Acc: 81.35%
# Epoch [242/1000], LR: 0.000100, Train Loss: 0.1695, Train Acc: 94.62%, Val Loss: 0.3502, Val Acc: 89.49%
# Epoch [243/1000], LR: 0.000100, Train Loss: 0.1662, Train Acc: 94.75%, Val Loss: 0.3250, Val Acc: 90.43%
# Epoch [244/1000], LR: 0.000010, Train Loss: 0.1573, Train Acc: 95.07%, Val Loss: 0.9397, Val Acc: 73.95%
# Epoch [245/1000], LR: 0.000100, Train Loss: 0.1658, Train Acc: 94.83%, Val Loss: 0.3285, Val Acc: 89.04%
# Epoch [246/1000], LR: 0.000100, Train Loss: 0.1651, Train Acc: 94.78%, Val Loss: 0.4275, Val Acc: 85.58%
# Epoch [247/1000], LR: 0.000100, Train Loss: 0.1621, Train Acc: 94.91%, Val Loss: 0.1589, Val Acc: 94.96%
# Epoch [248/1000], LR: 0.000010, Train Loss: 0.1565, Train Acc: 95.06%, Val Loss: 0.2039, Val Acc: 93.66%
# Epoch [249/1000], LR: 0.000010, Train Loss: 0.1605, Train Acc: 94.96%, Val Loss: 0.3880, Val Acc: 87.87%
# Epoch [250/1000], LR: 0.000100, Train Loss: 0.1653, Train Acc: 94.83%, Val Loss: 0.5635, Val Acc: 81.26%
# Epoch [251/1000], LR: 0.000100, Train Loss: 0.1624, Train Acc: 94.91%, Val Loss: 0.1777, Val Acc: 94.47%
# Epoch [252/1000], LR: 0.000010, Train Loss: 0.1566, Train Acc: 95.11%, Val Loss: 0.2034, Val Acc: 93.76%
# Epoch [253/1000], LR: 0.000010, Train Loss: 0.1522, Train Acc: 95.12%, Val Loss: 0.4472, Val Acc: 86.07%
# Epoch [254/1000], LR: 0.000100, Train Loss: 0.1660, Train Acc: 94.86%, Val Loss: 0.2190, Val Acc: 93.25%
# Epoch [255/1000], LR: 0.000010, Train Loss: 0.1573, Train Acc: 95.13%, Val Loss: 0.1554, Val Acc: 94.96%
# Epoch [256/1000], LR: 0.000010, Train Loss: 0.1542, Train Acc: 95.11%, Val Loss: 0.2236, Val Acc: 93.43%
# Epoch [257/1000], LR: 0.000010, Train Loss: 0.1580, Train Acc: 95.08%, Val Loss: 0.1676, Val Acc: 94.71%
# Epoch [258/1000], LR: 0.000010, Train Loss: 0.1571, Train Acc: 95.08%, Val Loss: 0.1589, Val Acc: 95.19%
# Epoch [259/1000], LR: 0.000010, Train Loss: 0.1569, Train Acc: 95.08%, Val Loss: 0.1659, Val Acc: 95.03%
# Epoch [260/1000], LR: 0.000010, Train Loss: 0.1554, Train Acc: 95.07%, Val Loss: 0.1678, Val Acc: 94.70%
# Epoch [261/1000], LR: 0.000010, Train Loss: 0.1588, Train Acc: 95.00%, Val Loss: 0.1532, Val Acc: 95.37%
# Epoch [262/1000], LR: 0.000010, Train Loss: 0.1513, Train Acc: 95.29%, Val Loss: 0.3007, Val Acc: 90.67%
# Epoch [263/1000], LR: 0.000010, Train Loss: 0.1531, Train Acc: 95.15%, Val Loss: 0.2715, Val Acc: 91.45%
# Epoch [264/1000], LR: 0.000010, Train Loss: 0.1563, Train Acc: 95.09%, Val Loss: 0.1688, Val Acc: 94.78%
# Epoch [265/1000], LR: 0.000010, Train Loss: 0.1552, Train Acc: 95.16%, Val Loss: 0.2218, Val Acc: 92.78%
# Epoch [266/1000], LR: 0.000010, Train Loss: 0.1606, Train Acc: 95.03%, Val Loss: 0.3307, Val Acc: 89.45%
# Epoch [267/1000], LR: 0.000100, Train Loss: 0.1654, Train Acc: 94.73%, Val Loss: 0.1773, Val Acc: 94.51%
# Epoch [268/1000], LR: 0.000010, Train Loss: 0.1523, Train Acc: 95.18%, Val Loss: 0.2291, Val Acc: 92.69%
# Epoch [269/1000], LR: 0.000010, Train Loss: 0.1546, Train Acc: 95.11%, Val Loss: 0.3976, Val Acc: 88.11%
# Epoch [270/1000], LR: 0.000100, Train Loss: 0.1617, Train Acc: 94.81%, Val Loss: 0.2584, Val Acc: 91.34%
# Epoch [271/1000], LR: 0.000010, Train Loss: 0.1510, Train Acc: 95.14%, Val Loss: 0.2352, Val Acc: 92.60%
# Epoch [272/1000], LR: 0.000010, Train Loss: 0.1561, Train Acc: 95.08%, Val Loss: 0.1474, Val Acc: 95.47%
# Epoch [273/1000], LR: 0.000010, Train Loss: 0.1564, Train Acc: 95.06%, Val Loss: 0.1438, Val Acc: 95.52%
# Epoch [274/1000], LR: 0.000010, Train Loss: 0.1559, Train Acc: 95.06%, Val Loss: 0.2533, Val Acc: 91.67%
# Epoch [275/1000], LR: 0.000010, Train Loss: 0.1543, Train Acc: 95.16%, Val Loss: 0.1641, Val Acc: 94.94%
# Epoch [276/1000], LR: 0.000010, Train Loss: 0.1582, Train Acc: 95.02%, Val Loss: 0.1769, Val Acc: 94.54%
# Epoch [277/1000], LR: 0.000010, Train Loss: 0.1589, Train Acc: 94.95%, Val Loss: 1.5432, Val Acc: 62.53%
# Epoch [278/1000], LR: 0.000100, Train Loss: 0.1673, Train Acc: 94.71%, Val Loss: 0.1997, Val Acc: 93.95%
# Epoch [279/1000], LR: 0.000010, Train Loss: 0.1532, Train Acc: 95.15%, Val Loss: 1.3373, Val Acc: 65.34%
# Epoch [280/1000], LR: 0.000100, Train Loss: 0.1638, Train Acc: 94.86%, Val Loss: 0.3149, Val Acc: 89.53%
# Epoch [281/1000], LR: 0.000100, Train Loss: 0.1616, Train Acc: 94.87%, Val Loss: 0.1511, Val Acc: 95.44%
# Epoch [282/1000], LR: 0.000010, Train Loss: 0.1489, Train Acc: 95.36%, Val Loss: 0.2026, Val Acc: 93.58%
# Epoch [283/1000], LR: 0.000010, Train Loss: 0.1534, Train Acc: 95.20%, Val Loss: 0.4074, Val Acc: 86.03%
# Epoch [284/1000], LR: 0.000100, Train Loss: 0.1629, Train Acc: 94.78%, Val Loss: 0.2329, Val Acc: 92.83%
# Epoch [285/1000], LR: 0.000010, Train Loss: 0.1575, Train Acc: 95.10%, Val Loss: 0.1657, Val Acc: 95.12%
# Epoch [286/1000], LR: 0.000010, Train Loss: 0.1533, Train Acc: 95.13%, Val Loss: 0.6881, Val Acc: 79.88%
# Epoch [287/1000], LR: 0.000100, Train Loss: 0.1644, Train Acc: 94.78%, Val Loss: 0.2504, Val Acc: 91.69%
# Epoch [288/1000], LR: 0.000010, Train Loss: 0.1541, Train Acc: 95.11%, Val Loss: 0.5093, Val Acc: 84.16%
# Epoch [289/1000], LR: 0.000100, Train Loss: 0.1628, Train Acc: 94.94%, Val Loss: 0.3265, Val Acc: 89.79%
# Epoch [290/1000], LR: 0.000100, Train Loss: 0.1612, Train Acc: 94.95%, Val Loss: 0.1471, Val Acc: 95.33%
# Epoch [291/1000], LR: 0.000010, Train Loss: 0.1525, Train Acc: 95.14%, Val Loss: 0.1527, Val Acc: 95.39%
# Epoch [292/1000], LR: 0.000010, Train Loss: 0.1489, Train Acc: 95.35%, Val Loss: 0.7610, Val Acc: 77.14%
# Epoch [293/1000], LR: 0.000100, Train Loss: 0.1617, Train Acc: 94.87%, Val Loss: 0.1894, Val Acc: 94.13%
# Epoch [294/1000], LR: 0.000010, Train Loss: 0.1501, Train Acc: 95.29%, Val Loss: 0.1477, Val Acc: 95.57%
# Epoch [295/1000], LR: 0.000010, Train Loss: 0.1534, Train Acc: 95.19%, Val Loss: 0.1454, Val Acc: 95.78%
# Epoch [296/1000], LR: 0.000010, Train Loss: 0.1555, Train Acc: 95.05%, Val Loss: 0.2335, Val Acc: 92.39%
# Epoch [297/1000], LR: 0.000010, Train Loss: 0.1548, Train Acc: 95.03%, Val Loss: 0.3826, Val Acc: 88.66%
# Epoch [298/1000], LR: 0.000100, Train Loss: 0.1612, Train Acc: 95.00%, Val Loss: 0.2619, Val Acc: 91.95%
# Epoch [299/1000], LR: 0.000010, Train Loss: 0.1535, Train Acc: 95.19%, Val Loss: 0.2077, Val Acc: 93.25%
# Epoch [300/1000], LR: 0.000010, Train Loss: 0.1541, Train Acc: 95.15%, Val Loss: 0.1613, Val Acc: 94.79%
# Epoch [301/1000], LR: 0.000010, Train Loss: 0.1587, Train Acc: 95.05%, Val Loss: 0.1589, Val Acc: 95.21%
# Epoch [302/1000], LR: 0.000010, Train Loss: 0.1537, Train Acc: 95.22%, Val Loss: 0.1897, Val Acc: 94.08%
# Epoch [303/1000], LR: 0.000010, Train Loss: 0.1561, Train Acc: 95.09%, Val Loss: 0.4384, Val Acc: 85.99%
# Epoch [304/1000], LR: 0.000100, Train Loss: 0.1648, Train Acc: 94.75%, Val Loss: 0.2195, Val Acc: 93.08%
# Epoch [305/1000], LR: 0.000010, Train Loss: 0.1547, Train Acc: 95.15%, Val Loss: 0.1721, Val Acc: 94.50%
# Epoch [306/1000], LR: 0.000010, Train Loss: 0.1501, Train Acc: 95.37%, Val Loss: 0.1553, Val Acc: 95.37%
# Epoch [307/1000], LR: 0.000010, Train Loss: 0.1531, Train Acc: 95.16%, Val Loss: 0.1515, Val Acc: 95.22%
# Epoch [308/1000], LR: 0.000010, Train Loss: 0.1538, Train Acc: 95.30%, Val Loss: 0.3525, Val Acc: 88.31%
# Epoch [309/1000], LR: 0.000100, Train Loss: 0.1644, Train Acc: 94.76%, Val Loss: 0.3147, Val Acc: 89.68%
# Epoch [310/1000], LR: 0.000100, Train Loss: 0.1580, Train Acc: 95.06%, Val Loss: 0.2777, Val Acc: 90.92%
# Epoch [311/1000], LR: 0.000010, Train Loss: 0.1538, Train Acc: 95.17%, Val Loss: 0.1768, Val Acc: 94.53%
# Epoch [312/1000], LR: 0.000010, Train Loss: 0.1495, Train Acc: 95.26%, Val Loss: 0.1521, Val Acc: 95.25%
# Epoch [313/1000], LR: 0.000010, Train Loss: 0.1539, Train Acc: 95.22%, Val Loss: 0.3155, Val Acc: 89.83%
# Epoch [314/1000], LR: 0.000100, Train Loss: 0.1592, Train Acc: 94.98%, Val Loss: 0.1593, Val Acc: 94.88%
# Epoch [315/1000], LR: 0.000010, Train Loss: 0.1512, Train Acc: 95.29%, Val Loss: 0.2193, Val Acc: 93.16%
# Epoch [316/1000], LR: 0.000010, Train Loss: 0.1511, Train Acc: 95.21%, Val Loss: 0.2593, Val Acc: 91.97%
# Epoch [317/1000], LR: 0.000010, Train Loss: 0.1491, Train Acc: 95.24%, Val Loss: 0.2132, Val Acc: 93.69%
# Epoch [318/1000], LR: 0.000010, Train Loss: 0.1510, Train Acc: 95.12%, Val Loss: 0.1409, Val Acc: 95.51%
# Epoch [319/1000], LR: 0.000010, Train Loss: 0.1506, Train Acc: 95.35%, Val Loss: 0.4511, Val Acc: 84.97%
# Epoch [320/1000], LR: 0.000100, Train Loss: 0.1655, Train Acc: 94.80%, Val Loss: 0.2175, Val Acc: 93.14%
# Epoch [321/1000], LR: 0.000010, Train Loss: 0.1546, Train Acc: 95.15%, Val Loss: 0.1678, Val Acc: 95.04%
# Epoch [322/1000], LR: 0.000010, Train Loss: 0.1499, Train Acc: 95.20%, Val Loss: 0.1555, Val Acc: 95.12%
# Epoch [323/1000], LR: 0.000010, Train Loss: 0.1514, Train Acc: 95.21%, Val Loss: 0.1390, Val Acc: 95.77%
# Epoch [324/1000], LR: 0.000010, Train Loss: 0.1536, Train Acc: 95.19%, Val Loss: 0.1904, Val Acc: 93.64%
# Epoch [325/1000], LR: 0.000010, Train Loss: 0.1531, Train Acc: 95.18%, Val Loss: 0.3370, Val Acc: 89.07%
# Epoch [326/1000], LR: 0.000100, Train Loss: 0.1623, Train Acc: 94.95%, Val Loss: 0.2024, Val Acc: 93.71%
# Epoch [327/1000], LR: 0.000010, Train Loss: 0.1504, Train Acc: 95.17%, Val Loss: 0.1654, Val Acc: 94.83%
# Epoch [328/1000], LR: 0.000010, Train Loss: 0.1508, Train Acc: 95.22%, Val Loss: 0.1396, Val Acc: 95.58%
# Epoch [329/1000], LR: 0.000010, Train Loss: 0.1538, Train Acc: 95.08%, Val Loss: 0.1667, Val Acc: 95.10%
# Epoch [330/1000], LR: 0.000010, Train Loss: 0.1586, Train Acc: 94.96%, Val Loss: 0.1421, Val Acc: 95.66%
# Epoch [331/1000], LR: 0.000010, Train Loss: 0.1531, Train Acc: 95.14%, Val Loss: 0.1828, Val Acc: 94.47%
# Epoch [332/1000], LR: 0.000010, Train Loss: 0.1552, Train Acc: 95.02%, Val Loss: 0.1894, Val Acc: 93.92%
# Epoch [333/1000], LR: 0.000010, Train Loss: 0.1537, Train Acc: 95.24%, Val Loss: 0.3311, Val Acc: 89.92%
# Epoch [334/1000], LR: 0.000100, Train Loss: 0.1648, Train Acc: 94.87%, Val Loss: 0.2711, Val Acc: 91.68%
# Epoch [335/1000], LR: 0.000010, Train Loss: 0.1516, Train Acc: 95.25%, Val Loss: 0.2308, Val Acc: 92.69%
# Epoch [336/1000], LR: 0.000010, Train Loss: 0.1513, Train Acc: 95.04%, Val Loss: 0.1732, Val Acc: 94.61%
# Epoch [337/1000], LR: 0.000010, Train Loss: 0.1532, Train Acc: 95.10%, Val Loss: 0.2061, Val Acc: 93.71%
# Epoch [338/1000], LR: 0.000010, Train Loss: 0.1536, Train Acc: 95.08%, Val Loss: 0.2235, Val Acc: 93.17%
# Epoch [339/1000], LR: 0.000010, Train Loss: 0.1514, Train Acc: 95.20%, Val Loss: 0.2621, Val Acc: 91.69%
# Epoch [340/1000], LR: 0.000010, Train Loss: 0.1533, Train Acc: 95.19%, Val Loss: 0.4075, Val Acc: 88.08%
# Epoch [341/1000], LR: 0.000100, Train Loss: 0.1629, Train Acc: 94.90%, Val Loss: 0.2283, Val Acc: 92.35%
# Epoch [342/1000], LR: 0.000010, Train Loss: 0.1532, Train Acc: 95.18%, Val Loss: 0.1598, Val Acc: 94.98%
# Epoch [343/1000], LR: 0.000010, Train Loss: 0.1526, Train Acc: 95.11%, Val Loss: 0.1590, Val Acc: 95.34%
# Epoch [344/1000], LR: 0.000010, Train Loss: 0.1496, Train Acc: 95.35%, Val Loss: 0.3885, Val Acc: 88.11%
# Epoch [345/1000], LR: 0.000100, Train Loss: 0.1597, Train Acc: 94.97%, Val Loss: 1.0683, Val Acc: 67.08%
# Epoch [346/1000], LR: 0.000100, Train Loss: 0.1588, Train Acc: 94.98%, Val Loss: 0.3693, Val Acc: 88.76%
# Epoch [347/1000], LR: 0.000100, Train Loss: 0.1610, Train Acc: 94.99%, Val Loss: 0.2445, Val Acc: 92.01%
# Epoch [348/1000], LR: 0.000010, Train Loss: 0.1552, Train Acc: 95.14%, Val Loss: 0.3574, Val Acc: 88.04%
# Epoch [349/1000], LR: 0.000100, Train Loss: 0.1602, Train Acc: 94.95%, Val Loss: 0.1579, Val Acc: 95.00%
# Epoch [350/1000], LR: 0.000010, Train Loss: 0.1450, Train Acc: 95.40%, Val Loss: 0.1899, Val Acc: 93.86%
# Epoch [351/1000], LR: 0.000010, Train Loss: 0.1490, Train Acc: 95.36%, Val Loss: 0.2735, Val Acc: 91.02%
# Epoch [352/1000], LR: 0.000010, Train Loss: 0.1514, Train Acc: 95.19%, Val Loss: 0.1736, Val Acc: 94.79%
# Epoch [353/1000], LR: 0.000010, Train Loss: 0.1507, Train Acc: 95.23%, Val Loss: 0.3165, Val Acc: 89.75%
# Epoch [354/1000], LR: 0.000100, Train Loss: 0.1614, Train Acc: 94.89%, Val Loss: 0.1516, Val Acc: 95.28%
# Epoch [355/1000], LR: 0.000010, Train Loss: 0.1471, Train Acc: 95.37%, Val Loss: 0.1490, Val Acc: 95.59%
# Epoch [356/1000], LR: 0.000010, Train Loss: 0.1474, Train Acc: 95.38%, Val Loss: 0.1506, Val Acc: 95.26%
# Epoch [357/1000], LR: 0.000010, Train Loss: 0.1542, Train Acc: 95.15%, Val Loss: 0.2571, Val Acc: 91.53%
# Epoch [358/1000], LR: 0.000010, Train Loss: 0.1556, Train Acc: 95.06%, Val Loss: 0.5045, Val Acc: 83.34%
# Epoch [359/1000], LR: 0.000100, Train Loss: 0.1647, Train Acc: 94.81%, Val Loss: 0.3098, Val Acc: 90.21%
# Epoch [360/1000], LR: 0.000010, Train Loss: 0.1502, Train Acc: 95.20%, Val Loss: 0.3532, Val Acc: 88.24%
# Epoch [361/1000], LR: 0.000100, Train Loss: 0.1607, Train Acc: 94.96%, Val Loss: 0.2881, Val Acc: 90.53%
# Epoch [362/1000], LR: 0.000010, Train Loss: 0.1510, Train Acc: 95.26%, Val Loss: 0.2401, Val Acc: 92.30%
# Epoch [363/1000], LR: 0.000010, Train Loss: 0.1487, Train Acc: 95.35%, Val Loss: 0.2018, Val Acc: 93.96%
# Epoch [364/1000], LR: 0.000010, Train Loss: 0.1509, Train Acc: 95.11%, Val Loss: 0.3465, Val Acc: 88.54%
# Epoch [365/1000], LR: 0.000100, Train Loss: 0.1594, Train Acc: 94.97%, Val Loss: 0.1806, Val Acc: 94.25%
# Epoch [366/1000], LR: 0.000010, Train Loss: 0.1502, Train Acc: 95.24%, Val Loss: 0.1948, Val Acc: 93.87%
# Epoch [367/1000], LR: 0.000010, Train Loss: 0.1526, Train Acc: 95.24%, Val Loss: 0.2506, Val Acc: 91.69%
# Epoch [368/1000], LR: 0.000010, Train Loss: 0.1511, Train Acc: 95.29%, Val Loss: 0.1610, Val Acc: 95.03%
# Epoch [369/1000], LR: 0.000010, Train Loss: 0.1520, Train Acc: 95.27%, Val Loss: 1.7307, Val Acc: 51.49%
# Epoch [370/1000], LR: 0.001000, Train Loss: 0.1795, Train Acc: 94.42%, Val Loss: 0.3455, Val Acc: 88.09%
# Epoch [371/1000], LR: 0.000100, Train Loss: 0.1561, Train Acc: 95.11%, Val Loss: 0.1774, Val Acc: 94.58%
# Epoch [372/1000], LR: 0.000010, Train Loss: 0.1468, Train Acc: 95.36%, Val Loss: 0.2103, Val Acc: 93.34%
# Epoch [373/1000], LR: 0.000010, Train Loss: 0.1477, Train Acc: 95.38%, Val Loss: 0.1869, Val Acc: 94.59%
# Epoch [374/1000], LR: 0.000010, Train Loss: 0.1454, Train Acc: 95.42%, Val Loss: 0.1778, Val Acc: 94.48%
# Epoch [375/1000], LR: 0.000010, Train Loss: 0.1496, Train Acc: 95.31%, Val Loss: 0.2451, Val Acc: 92.57%
# Epoch [376/1000], LR: 0.000010, Train Loss: 0.1504, Train Acc: 95.26%, Val Loss: 1.3372, Val Acc: 63.22%
# Epoch [377/1000], LR: 0.000100, Train Loss: 0.1578, Train Acc: 94.99%, Val Loss: 0.3949, Val Acc: 87.04%
# Epoch [378/1000], LR: 0.000100, Train Loss: 0.1541, Train Acc: 95.21%, Val Loss: 0.2870, Val Acc: 91.12%
# Epoch [379/1000], LR: 0.000010, Train Loss: 0.1452, Train Acc: 95.46%, Val Loss: 0.2542, Val Acc: 91.93%
# Epoch [380/1000], LR: 0.000010, Train Loss: 0.1477, Train Acc: 95.32%, Val Loss: 0.2319, Val Acc: 92.88%
# Epoch [381/1000], LR: 0.000010, Train Loss: 0.1473, Train Acc: 95.31%, Val Loss: 0.1891, Val Acc: 94.08%
# Epoch [382/1000], LR: 0.000010, Train Loss: 0.1470, Train Acc: 95.39%, Val Loss: 0.1977, Val Acc: 93.95%
# Epoch [383/1000], LR: 0.000010, Train Loss: 0.1507, Train Acc: 95.22%, Val Loss: 0.2447, Val Acc: 91.72%
# Epoch [384/1000], LR: 0.000010, Train Loss: 0.1521, Train Acc: 95.27%, Val Loss: 0.1483, Val Acc: 95.38%
# Epoch [385/1000], LR: 0.000010, Train Loss: 0.1551, Train Acc: 95.12%, Val Loss: 0.2557, Val Acc: 91.61%
# Epoch [386/1000], LR: 0.000010, Train Loss: 0.1478, Train Acc: 95.34%, Val Loss: 0.1583, Val Acc: 94.88%
# Epoch [387/1000], LR: 0.000010, Train Loss: 0.1499, Train Acc: 95.32%, Val Loss: 0.1825, Val Acc: 94.65%
# Epoch [388/1000], LR: 0.000010, Train Loss: 0.1506, Train Acc: 95.30%, Val Loss: 0.1661, Val Acc: 95.06%
# Epoch [389/1000], LR: 0.000010, Train Loss: 0.1513, Train Acc: 95.25%, Val Loss: 1.2991, Val Acc: 69.02%
# Epoch [390/1000], LR: 0.000100, Train Loss: 0.1568, Train Acc: 95.13%, Val Loss: 0.2526, Val Acc: 92.19%
# Epoch [391/1000], LR: 0.000010, Train Loss: 0.1525, Train Acc: 95.22%, Val Loss: 0.1633, Val Acc: 94.88%
# Epoch [392/1000], LR: 0.000010, Train Loss: 0.1464, Train Acc: 95.45%, Val Loss: 0.1405, Val Acc: 95.67%
# Epoch [393/1000], LR: 0.000010, Train Loss: 0.1470, Train Acc: 95.33%, Val Loss: 0.1691, Val Acc: 94.77%
# Epoch [394/1000], LR: 0.000010, Train Loss: 0.1506, Train Acc: 95.34%, Val Loss: 0.1451, Val Acc: 95.28%
# Epoch [395/1000], LR: 0.000010, Train Loss: 0.1467, Train Acc: 95.45%, Val Loss: 0.2478, Val Acc: 91.63%
# Epoch [396/1000], LR: 0.000010, Train Loss: 0.1483, Train Acc: 95.32%, Val Loss: 0.3765, Val Acc: 87.33%
# Epoch [397/1000], LR: 0.000100, Train Loss: 0.1557, Train Acc: 95.09%, Val Loss: 0.2216, Val Acc: 93.18%
# Epoch [398/1000], LR: 0.000010, Train Loss: 0.1477, Train Acc: 95.41%, Val Loss: 0.2153, Val Acc: 93.28%
# Epoch [399/1000], LR: 0.000010, Train Loss: 0.1463, Train Acc: 95.31%, Val Loss: 0.1491, Val Acc: 95.38%
# Epoch [400/1000], LR: 0.000010, Train Loss: 0.1508, Train Acc: 95.35%, Val Loss: 0.3927, Val Acc: 86.62%
# Epoch [401/1000], LR: 0.000100, Train Loss: 0.1565, Train Acc: 95.10%, Val Loss: 0.1401, Val Acc: 95.53%
# Epoch [402/1000], LR: 0.000010, Train Loss: 0.1460, Train Acc: 95.43%, Val Loss: 0.1370, Val Acc: 95.88%
# Epoch [403/1000], LR: 0.000010, Train Loss: 0.1466, Train Acc: 95.38%, Val Loss: 1.1286, Val Acc: 70.29%
# Epoch [404/1000], LR: 0.000100, Train Loss: 0.1571, Train Acc: 94.94%, Val Loss: 0.6580, Val Acc: 78.88%
# Epoch [405/1000], LR: 0.000100, Train Loss: 0.1538, Train Acc: 95.09%, Val Loss: 0.1728, Val Acc: 94.47%
# Epoch [406/1000], LR: 0.000010, Train Loss: 0.1412, Train Acc: 95.56%, Val Loss: 0.1914, Val Acc: 94.03%
# Epoch [407/1000], LR: 0.000010, Train Loss: 0.1454, Train Acc: 95.40%, Val Loss: 0.1582, Val Acc: 94.97%
# Epoch [408/1000], LR: 0.000010, Train Loss: 0.1466, Train Acc: 95.36%, Val Loss: 0.1535, Val Acc: 95.22%
# Epoch [409/1000], LR: 0.000010, Train Loss: 0.1475, Train Acc: 95.36%, Val Loss: 0.2982, Val Acc: 90.49%
# Epoch [410/1000], LR: 0.000010, Train Loss: 0.1478, Train Acc: 95.39%, Val Loss: 0.2647, Val Acc: 91.21%
# Epoch [411/1000], LR: 0.000010, Train Loss: 0.1509, Train Acc: 95.26%, Val Loss: 0.4387, Val Acc: 86.57%
# Epoch [412/1000], LR: 0.000100, Train Loss: 0.1519, Train Acc: 95.23%, Val Loss: 0.3975, Val Acc: 86.41%
# Epoch [413/1000], LR: 0.000100, Train Loss: 0.1542, Train Acc: 95.16%, Val Loss: 0.2327, Val Acc: 92.42%
# Epoch [414/1000], LR: 0.000010, Train Loss: 0.1474, Train Acc: 95.25%, Val Loss: 0.2283, Val Acc: 93.08%
# Epoch [415/1000], LR: 0.000010, Train Loss: 0.1463, Train Acc: 95.42%, Val Loss: 0.9542, Val Acc: 69.39%
# Epoch [416/1000], LR: 0.000100, Train Loss: 0.1520, Train Acc: 95.19%, Val Loss: 0.4985, Val Acc: 84.10%
# Epoch [417/1000], LR: 0.000100, Train Loss: 0.1569, Train Acc: 95.14%, Val Loss: 0.7846, Val Acc: 75.40%
# Epoch [418/1000], LR: 0.000100, Train Loss: 0.1568, Train Acc: 95.05%, Val Loss: 0.1723, Val Acc: 94.76%
# Epoch [419/1000], LR: 0.000010, Train Loss: 0.1445, Train Acc: 95.45%, Val Loss: 0.2303, Val Acc: 92.58%
# Epoch [420/1000], LR: 0.000010, Train Loss: 0.1441, Train Acc: 95.47%, Val Loss: 0.1483, Val Acc: 95.46%
# Epoch [421/1000], LR: 0.000010, Train Loss: 0.1474, Train Acc: 95.32%, Val Loss: 0.1742, Val Acc: 94.40%
# Epoch [422/1000], LR: 0.000010, Train Loss: 0.1490, Train Acc: 95.27%, Val Loss: 0.1754, Val Acc: 94.45%
# Epoch [423/1000], LR: 0.000010, Train Loss: 0.1477, Train Acc: 95.30%, Val Loss: 0.3668, Val Acc: 87.98%
# Epoch [424/1000], LR: 0.000100, Train Loss: 0.1528, Train Acc: 95.25%, Val Loss: 0.2686, Val Acc: 90.83%
# Epoch [425/1000], LR: 0.000010, Train Loss: 0.1426, Train Acc: 95.45%, Val Loss: 0.1835, Val Acc: 94.30%
# Epoch [426/1000], LR: 0.000010, Train Loss: 0.1476, Train Acc: 95.30%, Val Loss: 0.4352, Val Acc: 86.81%
# Epoch [427/1000], LR: 0.000100, Train Loss: 0.1574, Train Acc: 94.99%, Val Loss: 0.2500, Val Acc: 92.29%
# Epoch [428/1000], LR: 0.000010, Train Loss: 0.1467, Train Acc: 95.37%, Val Loss: 0.1935, Val Acc: 94.07%
# Epoch [429/1000], LR: 0.000010, Train Loss: 0.1473, Train Acc: 95.36%, Val Loss: 0.1406, Val Acc: 95.66%
# Epoch [430/1000], LR: 0.000010, Train Loss: 0.1462, Train Acc: 95.41%, Val Loss: 0.1719, Val Acc: 94.69%
# Epoch [431/1000], LR: 0.000010, Train Loss: 0.1488, Train Acc: 95.37%, Val Loss: 0.4071, Val Acc: 85.70%
# Epoch [432/1000], LR: 0.000100, Train Loss: 0.1528, Train Acc: 95.11%, Val Loss: 0.1852, Val Acc: 94.34%
# Epoch [433/1000], LR: 0.000010, Train Loss: 0.1415, Train Acc: 95.54%, Val Loss: 0.2383, Val Acc: 92.72%
# Epoch [434/1000], LR: 0.000010, Train Loss: 0.1418, Train Acc: 95.56%, Val Loss: 0.1633, Val Acc: 94.74%
# Epoch [435/1000], LR: 0.000010, Train Loss: 0.1407, Train Acc: 95.67%, Val Loss: 0.2826, Val Acc: 91.46%
# Epoch [436/1000], LR: 0.000010, Train Loss: 0.1462, Train Acc: 95.31%, Val Loss: 0.3612, Val Acc: 88.41%
# Epoch [437/1000], LR: 0.000100, Train Loss: 0.1556, Train Acc: 95.02%, Val Loss: 0.2006, Val Acc: 93.69%
# Epoch [438/1000], LR: 0.000010, Train Loss: 0.1425, Train Acc: 95.45%, Val Loss: 0.2179, Val Acc: 93.06%
# Epoch [439/1000], LR: 0.000010, Train Loss: 0.1480, Train Acc: 95.38%, Val Loss: 0.1667, Val Acc: 94.77%
# Epoch [440/1000], LR: 0.000010, Train Loss: 0.1486, Train Acc: 95.37%, Val Loss: 0.1411, Val Acc: 95.80%
# Epoch [441/1000], LR: 0.000010, Train Loss: 0.1450, Train Acc: 95.49%, Val Loss: 0.1399, Val Acc: 95.72%
# Epoch [442/1000], LR: 0.000010, Train Loss: 0.1482, Train Acc: 95.43%, Val Loss: 0.4761, Val Acc: 84.43%
# Epoch [443/1000], LR: 0.000100, Train Loss: 0.1544, Train Acc: 95.24%, Val Loss: 0.1972, Val Acc: 93.86%
# Epoch [444/1000], LR: 0.000010, Train Loss: 0.1442, Train Acc: 95.50%, Val Loss: 0.2200, Val Acc: 93.42%
# Epoch [445/1000], LR: 0.000010, Train Loss: 0.1463, Train Acc: 95.41%, Val Loss: 0.2358, Val Acc: 92.33%
# Epoch [446/1000], LR: 0.000010, Train Loss: 0.1445, Train Acc: 95.45%, Val Loss: 0.1355, Val Acc: 95.86%
# Epoch [447/1000], LR: 0.000010, Train Loss: 0.1489, Train Acc: 95.30%, Val Loss: 0.1626, Val Acc: 94.80%
# Epoch [448/1000], LR: 0.000010, Train Loss: 0.1469, Train Acc: 95.44%, Val Loss: 0.2365, Val Acc: 92.73%
# Epoch [449/1000], LR: 0.000010, Train Loss: 0.1470, Train Acc: 95.40%, Val Loss: 0.1881, Val Acc: 94.28%
# Epoch [450/1000], LR: 0.000010, Train Loss: 0.1471, Train Acc: 95.42%, Val Loss: 0.3515, Val Acc: 89.31%
# Epoch [451/1000], LR: 0.000100, Train Loss: 0.1549, Train Acc: 95.07%, Val Loss: 0.2214, Val Acc: 92.97%
# Epoch [452/1000], LR: 0.000010, Train Loss: 0.1427, Train Acc: 95.47%, Val Loss: 0.3604, Val Acc: 87.79%
# ...
# Epoch [850/1000], LR: 0.000100, Train Loss: 0.1365, Train Acc: 95.66%, Val Loss: 0.1280, Val Acc: 95.99%
# Epoch [851/1000], LR: 0.000010, Train Loss: 0.1291, Train Acc: 95.98%, Val Loss: 0.1924, Val Acc: 93.68%
# Epoch [852/1000], LR: 0.000010, Train Loss: 0.1280, Train Acc: 96.04%, Val Loss: 0.4343, Val Acc: 87.10%
# Epoch [853/1000], LR: 0.000100, Train Loss: 0.1419, Train Acc: 95.45%, Val Loss: 0.4006, Val Acc: 87.33%
# Epoch [854/1000], LR: 0.000100, Train Loss: 0.1396, Train Acc: 95.65%, Val Loss: 0.1369, Val Acc: 95.78%
# Epoch [855/1000], LR: 0.000010, Train Loss: 0.1291, Train Acc: 95.97%, Val Loss: 0.1844, Val Acc: 94.22%
# Epoch [856/1000], LR: 0.000010, Train Loss: 0.1234, Train Acc: 96.15%, Val Loss: 0.1303, Val Acc: 95.76%
# Epoch [857/1000], LR: 0.000010, Train Loss: 0.1255, Train Acc: 95.97%, Val Loss: 0.3302, Val Acc: 89.57%
# Epoch [858/1000], LR: 0.000100, Train Loss: 0.1420, Train Acc: 95.55%, Val Loss: 0.9127, Val Acc: 69.92%
# Epoch [859/1000], LR: 0.000100, Train Loss: 0.1386, Train Acc: 95.74%, Val Loss: 0.1837, Val Acc: 94.46%
# Epoch [860/1000], LR: 0.000010, Train Loss: 0.1296, Train Acc: 95.88%, Val Loss: 0.1333, Val Acc: 95.69%
# Epoch [861/1000], LR: 0.000010, Train Loss: 0.1277, Train Acc: 96.03%, Val Loss: 0.3436, Val Acc: 88.10%
# Epoch [862/1000], LR: 0.000100, Train Loss: 0.1447, Train Acc: 95.46%, Val Loss: 0.2500, Val Acc: 92.26%
# Epoch [863/1000], LR: 0.000010, Train Loss: 0.1258, Train Acc: 96.03%, Val Loss: 0.1122, Val Acc: 96.34%
# Epoch [864/1000], LR: 0.000010, Train Loss: 0.1270, Train Acc: 95.91%, Val Loss: 0.2083, Val Acc: 93.55%
# Epoch [865/1000], LR: 0.000010, Train Loss: 0.1285, Train Acc: 95.99%, Val Loss: 0.1987, Val Acc: 93.84%
# Epoch [866/1000], LR: 0.000010, Train Loss: 0.1269, Train Acc: 96.00%, Val Loss: 0.2165, Val Acc: 93.26%
# Epoch [867/1000], LR: 0.000010, Train Loss: 0.1277, Train Acc: 96.04%, Val Loss: 0.1526, Val Acc: 95.06%
# Epoch [868/1000], LR: 0.000010, Train Loss: 0.1299, Train Acc: 95.94%, Val Loss: 0.4233, Val Acc: 85.70%
# Epoch [869/1000], LR: 0.000100, Train Loss: 0.1413, Train Acc: 95.53%, Val Loss: 0.1337, Val Acc: 95.91%
# Epoch [870/1000], LR: 0.000010, Train Loss: 0.1287, Train Acc: 95.95%, Val Loss: 0.5175, Val Acc: 83.27%
# Epoch [871/1000], LR: 0.000100, Train Loss: 0.1391, Train Acc: 95.55%, Val Loss: 0.4198, Val Acc: 86.48%
# Epoch [872/1000], LR: 0.000100, Train Loss: 0.1367, Train Acc: 95.72%, Val Loss: 0.1336, Val Acc: 95.88%
# Epoch [873/1000], LR: 0.000010, Train Loss: 0.1231, Train Acc: 96.13%, Val Loss: 0.1187, Val Acc: 96.31%
# Epoch [874/1000], LR: 0.000010, Train Loss: 0.1281, Train Acc: 96.02%, Val Loss: 0.1349, Val Acc: 95.63%
# Epoch [875/1000], LR: 0.000010, Train Loss: 0.1280, Train Acc: 95.92%, Val Loss: 0.1194, Val Acc: 96.16%
# Epoch [876/1000], LR: 0.000010, Train Loss: 0.1298, Train Acc: 95.99%, Val Loss: 0.2038, Val Acc: 93.53%
# Epoch [877/1000], LR: 0.000010, Train Loss: 0.1284, Train Acc: 95.90%, Val Loss: 0.1478, Val Acc: 95.20%
# Epoch [878/1000], LR: 0.000010, Train Loss: 0.1329, Train Acc: 95.79%, Val Loss: 0.1299, Val Acc: 95.92%
# Epoch [879/1000], LR: 0.000010, Train Loss: 0.1301, Train Acc: 95.94%, Val Loss: 0.4325, Val Acc: 86.63%
# Epoch [880/1000], LR: 0.000100, Train Loss: 0.1394, Train Acc: 95.65%, Val Loss: 0.3792, Val Acc: 88.20%
# Epoch [881/1000], LR: 0.000100, Train Loss: 0.1422, Train Acc: 95.51%, Val Loss: 0.1455, Val Acc: 95.62%
# Epoch [882/1000], LR: 0.000010, Train Loss: 0.1274, Train Acc: 95.99%, Val Loss: 0.2328, Val Acc: 92.84%
# Epoch [883/1000], LR: 0.000010, Train Loss: 0.1237, Train Acc: 96.10%, Val Loss: 0.1437, Val Acc: 95.53%
# Epoch [884/1000], LR: 0.000010, Train Loss: 0.1289, Train Acc: 95.99%, Val Loss: 0.1950, Val Acc: 94.19%
# Epoch [885/1000], LR: 0.000010, Train Loss: 0.1291, Train Acc: 95.93%, Val Loss: 0.1641, Val Acc: 94.94%
# Epoch [886/1000], LR: 0.000010, Train Loss: 0.1286, Train Acc: 95.95%, Val Loss: 0.1578, Val Acc: 95.12%
# Epoch [887/1000], LR: 0.000010, Train Loss: 0.1254, Train Acc: 96.06%, Val Loss: 0.3177, Val Acc: 90.01%
# Epoch [888/1000], LR: 0.000010, Train Loss: 0.1293, Train Acc: 95.92%, Val Loss: 0.1615, Val Acc: 94.97%
# Epoch [889/1000], LR: 0.000010, Train Loss: 0.1290, Train Acc: 95.88%, Val Loss: 0.1767, Val Acc: 94.43%
# Epoch [890/1000], LR: 0.000010, Train Loss: 0.1304, Train Acc: 95.81%, Val Loss: 0.1525, Val Acc: 95.13%
# Epoch [891/1000], LR: 0.000010, Train Loss: 0.1299, Train Acc: 95.86%, Val Loss: 0.1423, Val Acc: 95.81%
# Epoch [892/1000], LR: 0.000010, Train Loss: 0.1304, Train Acc: 95.83%, Val Loss: 0.1406, Val Acc: 95.92%
# Epoch [893/1000], LR: 0.000010, Train Loss: 0.1291, Train Acc: 95.89%, Val Loss: 0.2037, Val Acc: 93.45%
# Epoch [894/1000], LR: 0.000010, Train Loss: 0.1313, Train Acc: 95.90%, Val Loss: 0.3148, Val Acc: 89.95%
# Epoch [895/1000], LR: 0.000100, Train Loss: 0.1393, Train Acc: 95.57%, Val Loss: 0.1584, Val Acc: 94.79%
# Epoch [896/1000], LR: 0.000010, Train Loss: 0.1294, Train Acc: 95.97%, Val Loss: 0.1771, Val Acc: 94.70%
# Epoch [897/1000], LR: 0.000010, Train Loss: 0.1212, Train Acc: 96.17%, Val Loss: 0.1239, Val Acc: 96.11%
# Epoch [898/1000], LR: 0.000010, Train Loss: 0.1246, Train Acc: 96.03%, Val Loss: 0.1484, Val Acc: 95.60%
# Epoch [899/1000], LR: 0.000010, Train Loss: 0.1295, Train Acc: 95.88%, Val Loss: 0.1252, Val Acc: 96.25%
# Epoch [900/1000], LR: 0.000010, Train Loss: 0.1270, Train Acc: 95.96%, Val Loss: 0.8941, Val Acc: 76.08%
# Epoch [901/1000], LR: 0.000100, Train Loss: 0.1414, Train Acc: 95.53%, Val Loss: 0.1865, Val Acc: 94.18%
# Epoch [902/1000], LR: 0.000010, Train Loss: 0.1203, Train Acc: 96.18%, Val Loss: 0.1707, Val Acc: 94.50%
# Epoch [903/1000], LR: 0.000010, Train Loss: 0.1258, Train Acc: 96.00%, Val Loss: 0.1384, Val Acc: 95.67%
# Epoch [904/1000], LR: 0.000010, Train Loss: 0.1274, Train Acc: 96.00%, Val Loss: 0.1553, Val Acc: 94.68%
# Epoch [905/1000], LR: 0.000010, Train Loss: 0.1272, Train Acc: 95.98%, Val Loss: 0.6952, Val Acc: 78.97%
# Epoch [906/1000], LR: 0.000100, Train Loss: 0.1377, Train Acc: 95.67%, Val Loss: 0.1753, Val Acc: 94.66%
# Epoch [907/1000], LR: 0.000010, Train Loss: 0.1235, Train Acc: 96.11%, Val Loss: 0.1440, Val Acc: 95.43%
# Epoch [908/1000], LR: 0.000010, Train Loss: 0.1252, Train Acc: 96.07%, Val Loss: 0.1382, Val Acc: 95.82%
# Epoch [909/1000], LR: 0.000010, Train Loss: 0.1244, Train Acc: 95.98%, Val Loss: 0.1364, Val Acc: 95.72%
# Epoch [910/1000], LR: 0.000010, Train Loss: 0.1243, Train Acc: 96.12%, Val Loss: 0.1386, Val Acc: 95.64%
# Epoch [911/1000], LR: 0.000010, Train Loss: 0.1272, Train Acc: 96.04%, Val Loss: 1.1886, Val Acc: 68.29%
# Epoch [912/1000], LR: 0.000100, Train Loss: 0.1432, Train Acc: 95.45%, Val Loss: 0.3008, Val Acc: 90.07%
# Epoch [913/1000], LR: 0.000010, Train Loss: 0.1259, Train Acc: 96.06%, Val Loss: 0.1373, Val Acc: 95.73%
# Epoch [914/1000], LR: 0.000010, Train Loss: 0.1247, Train Acc: 96.07%, Val Loss: 0.2294, Val Acc: 92.98%
# Epoch [915/1000], LR: 0.000010, Train Loss: 0.1253, Train Acc: 96.12%, Val Loss: 0.1314, Val Acc: 95.98%
# Epoch [916/1000], LR: 0.000010, Train Loss: 0.1297, Train Acc: 96.00%, Val Loss: 0.3932, Val Acc: 87.27%
# Epoch [917/1000], LR: 0.000100, Train Loss: 0.1409, Train Acc: 95.56%, Val Loss: 0.1903, Val Acc: 94.17%
# Epoch [918/1000], LR: 0.000010, Train Loss: 0.1284, Train Acc: 96.00%, Val Loss: 0.1279, Val Acc: 95.68%
# Epoch [919/1000], LR: 0.000010, Train Loss: 0.1268, Train Acc: 95.95%, Val Loss: 0.1306, Val Acc: 95.68%
# Epoch [920/1000], LR: 0.000010, Train Loss: 0.1267, Train Acc: 95.95%, Val Loss: 0.1313, Val Acc: 96.18%
# Epoch [921/1000], LR: 0.000010, Train Loss: 0.1298, Train Acc: 95.92%, Val Loss: 0.1224, Val Acc: 96.19%
# Epoch [922/1000], LR: 0.000010, Train Loss: 0.1289, Train Acc: 95.94%, Val Loss: 0.1275, Val Acc: 95.97%
# Epoch [923/1000], LR: 0.000010, Train Loss: 0.1294, Train Acc: 95.86%, Val Loss: 1.1404, Val Acc: 69.88%
# Epoch [924/1000], LR: 0.000100, Train Loss: 0.1391, Train Acc: 95.58%, Val Loss: 0.1350, Val Acc: 95.78%
# Epoch [925/1000], LR: 0.000010, Train Loss: 0.1290, Train Acc: 95.94%, Val Loss: 0.1302, Val Acc: 95.99%
# Epoch [926/1000], LR: 0.000010, Train Loss: 0.1243, Train Acc: 96.10%, Val Loss: 0.1261, Val Acc: 96.10%
# Epoch [927/1000], LR: 0.000010, Train Loss: 0.1239, Train Acc: 96.11%, Val Loss: 0.1436, Val Acc: 95.65%
# Epoch [928/1000], LR: 0.000010, Train Loss: 0.1287, Train Acc: 95.95%, Val Loss: 0.7992, Val Acc: 72.83%
# Epoch [929/1000], LR: 0.000100, Train Loss: 0.1410, Train Acc: 95.60%, Val Loss: 0.4690, Val Acc: 85.38%
# Epoch [930/1000], LR: 0.000100, Train Loss: 0.1391, Train Acc: 95.56%, Val Loss: 0.2737, Val Acc: 91.25%
# Epoch [931/1000], LR: 0.000010, Train Loss: 0.1290, Train Acc: 95.96%, Val Loss: 0.1661, Val Acc: 94.63%
# Epoch [932/1000], LR: 0.000010, Train Loss: 0.1251, Train Acc: 96.03%, Val Loss: 0.2344, Val Acc: 92.39%
# Epoch [933/1000], LR: 0.000010, Train Loss: 0.1253, Train Acc: 96.04%, Val Loss: 0.2156, Val Acc: 93.53%
# Epoch [934/1000], LR: 0.000010, Train Loss: 0.1295, Train Acc: 95.89%, Val Loss: 0.2181, Val Acc: 93.27%
# Epoch [935/1000], LR: 0.000010, Train Loss: 0.1275, Train Acc: 96.00%, Val Loss: 0.1337, Val Acc: 95.70%
# Epoch [936/1000], LR: 0.000010, Train Loss: 0.1253, Train Acc: 96.07%, Val Loss: 1.2389, Val Acc: 68.15%
# Epoch [937/1000], LR: 0.000100, Train Loss: 0.1407, Train Acc: 95.56%, Val Loss: 0.1337, Val Acc: 95.87%
# Epoch [938/1000], LR: 0.000010, Train Loss: 0.1281, Train Acc: 96.02%, Val Loss: 0.1342, Val Acc: 95.88%
# Epoch [939/1000], LR: 0.000010, Train Loss: 0.1247, Train Acc: 96.11%, Val Loss: 0.4689, Val Acc: 85.62%
# Epoch [940/1000], LR: 0.000100, Train Loss: 0.1379, Train Acc: 95.69%, Val Loss: 0.1546, Val Acc: 94.95%
# Epoch [941/1000], LR: 0.000010, Train Loss: 0.1285, Train Acc: 95.91%, Val Loss: 0.1276, Val Acc: 96.04%
# Epoch [942/1000], LR: 0.000010, Train Loss: 0.1255, Train Acc: 95.98%, Val Loss: 0.8978, Val Acc: 74.79%
# Epoch [943/1000], LR: 0.000100, Train Loss: 0.1406, Train Acc: 95.67%, Val Loss: 0.1413, Val Acc: 95.71%
# Epoch [944/1000], LR: 0.000010, Train Loss: 0.1286, Train Acc: 95.84%, Val Loss: 0.1495, Val Acc: 95.25%
# Epoch [945/1000], LR: 0.000010, Train Loss: 0.1237, Train Acc: 96.09%, Val Loss: 0.2388, Val Acc: 92.92%
# Epoch [946/1000], LR: 0.000010, Train Loss: 0.1255, Train Acc: 96.05%, Val Loss: 0.1426, Val Acc: 95.77%
# Epoch [947/1000], LR: 0.000010, Train Loss: 0.1273, Train Acc: 95.92%, Val Loss: 0.3256, Val Acc: 90.34%
# Epoch [948/1000], LR: 0.000010, Train Loss: 0.1299, Train Acc: 95.95%, Val Loss: 0.1263, Val Acc: 96.07%
# Epoch [949/1000], LR: 0.000010, Train Loss: 0.1259, Train Acc: 96.01%, Val Loss: 0.1384, Val Acc: 95.68%
# Epoch [950/1000], LR: 0.000010, Train Loss: 0.1247, Train Acc: 96.00%, Val Loss: 0.1305, Val Acc: 95.73%
# Epoch [951/1000], LR: 0.000010, Train Loss: 0.1293, Train Acc: 95.86%, Val Loss: 0.2100, Val Acc: 93.41%
# Epoch [952/1000], LR: 0.000010, Train Loss: 0.1293, Train Acc: 95.92%, Val Loss: 0.3389, Val Acc: 89.48%
# Epoch [953/1000], LR: 0.000100, Train Loss: 0.1430, Train Acc: 95.52%, Val Loss: 0.8260, Val Acc: 75.21%
# Epoch [954/1000], LR: 0.000100, Train Loss: 0.1376, Train Acc: 95.62%, Val Loss: 0.5696, Val Acc: 81.63%
# Epoch [955/1000], LR: 0.000100, Train Loss: 0.1360, Train Acc: 95.76%, Val Loss: 0.1572, Val Acc: 95.30%
# Epoch [956/1000], LR: 0.000010, Train Loss: 0.1248, Train Acc: 96.05%, Val Loss: 0.1314, Val Acc: 95.95%
# Epoch [957/1000], LR: 0.000010, Train Loss: 0.1255, Train Acc: 95.98%, Val Loss: 0.4568, Val Acc: 86.02%
# Epoch [958/1000], LR: 0.000100, Train Loss: 0.1372, Train Acc: 95.53%, Val Loss: 0.1527, Val Acc: 95.14%
# Epoch [959/1000], LR: 0.000010, Train Loss: 0.1273, Train Acc: 96.04%, Val Loss: 0.1632, Val Acc: 94.84%
# Epoch [960/1000], LR: 0.000010, Train Loss: 0.1276, Train Acc: 95.93%, Val Loss: 0.6071, Val Acc: 81.07%
# Epoch [961/1000], LR: 0.000100, Train Loss: 0.1399, Train Acc: 95.63%, Val Loss: 0.3131, Val Acc: 90.40%
# Epoch [962/1000], LR: 0.000010, Train Loss: 0.1281, Train Acc: 96.03%, Val Loss: 0.3333, Val Acc: 89.66%
# Epoch [963/1000], LR: 0.000100, Train Loss: 0.1395, Train Acc: 95.59%, Val Loss: 0.3269, Val Acc: 90.05%
# Epoch [964/1000], LR: 0.000010, Train Loss: 0.1238, Train Acc: 96.07%, Val Loss: 0.1363, Val Acc: 95.70%
# Epoch [965/1000], LR: 0.000010, Train Loss: 0.1200, Train Acc: 96.25%, Val Loss: 0.1834, Val Acc: 93.92%
# Epoch [966/1000], LR: 0.000010, Train Loss: 0.1271, Train Acc: 96.10%, Val Loss: 0.4967, Val Acc: 84.92%
# Epoch [967/1000], LR: 0.000100, Train Loss: 0.1382, Train Acc: 95.71%, Val Loss: 0.1581, Val Acc: 95.11%
# Epoch [968/1000], LR: 0.000010, Train Loss: 0.1282, Train Acc: 95.90%, Val Loss: 0.1401, Val Acc: 95.50%
# Epoch [969/1000], LR: 0.000010, Train Loss: 0.1253, Train Acc: 96.04%, Val Loss: 0.1934, Val Acc: 93.74%
# Epoch [970/1000], LR: 0.000010, Train Loss: 0.1231, Train Acc: 96.25%, Val Loss: 0.1402, Val Acc: 95.70%
# Epoch [971/1000], LR: 0.000010, Train Loss: 0.1263, Train Acc: 96.04%, Val Loss: 0.1782, Val Acc: 94.50%
# Epoch [972/1000], LR: 0.000010, Train Loss: 0.1233, Train Acc: 96.11%, Val Loss: 0.5041, Val Acc: 83.99%
# Epoch [973/1000], LR: 0.000100, Train Loss: 0.1397, Train Acc: 95.60%, Val Loss: 0.1401, Val Acc: 95.49%
# Epoch [974/1000], LR: 0.000010, Train Loss: 0.1222, Train Acc: 96.14%, Val Loss: 0.1217, Val Acc: 96.24%
# Epoch [975/1000], LR: 0.000010, Train Loss: 0.1267, Train Acc: 96.01%, Val Loss: 0.1368, Val Acc: 95.64%
# Epoch [976/1000], LR: 0.000010, Train Loss: 0.1245, Train Acc: 96.11%, Val Loss: 0.1287, Val Acc: 96.08%
# Epoch [977/1000], LR: 0.000010, Train Loss: 0.1253, Train Acc: 96.06%, Val Loss: 0.1330, Val Acc: 95.98%
# Epoch [978/1000], LR: 0.000010, Train Loss: 0.1257, Train Acc: 95.95%, Val Loss: 0.4984, Val Acc: 84.01%
# Epoch [979/1000], LR: 0.000100, Train Loss: 0.1411, Train Acc: 95.66%, Val Loss: 0.2872, Val Acc: 91.28%
# Epoch [980/1000], LR: 0.000010, Train Loss: 0.1235, Train Acc: 96.06%, Val Loss: 0.1771, Val Acc: 94.48%
# Epoch [981/1000], LR: 0.000010, Train Loss: 0.1249, Train Acc: 96.02%, Val Loss: 0.9218, Val Acc: 72.20%
# Epoch [982/1000], LR: 0.000100, Train Loss: 0.1400, Train Acc: 95.54%, Val Loss: 1.1011, Val Acc: 70.30%
# Epoch [983/1000], LR: 0.000100, Train Loss: 0.1358, Train Acc: 95.71%, Val Loss: 0.2436, Val Acc: 92.57%
# Epoch [984/1000], LR: 0.000010, Train Loss: 0.1234, Train Acc: 96.03%, Val Loss: 0.1252, Val Acc: 96.03%
# Epoch [985/1000], LR: 0.000010, Train Loss: 0.1263, Train Acc: 96.01%, Val Loss: 0.2451, Val Acc: 92.20%
# Epoch [986/1000], LR: 0.000010, Train Loss: 0.1281, Train Acc: 95.97%, Val Loss: 0.1169, Val Acc: 96.32%
# Epoch [987/1000], LR: 0.000010, Train Loss: 0.1258, Train Acc: 96.03%, Val Loss: 0.1286, Val Acc: 96.02%
# Epoch [988/1000], LR: 0.000010, Train Loss: 0.1242, Train Acc: 96.12%, Val Loss: 0.2433, Val Acc: 92.29%
# Epoch [989/1000], LR: 0.000010, Train Loss: 0.1262, Train Acc: 96.05%, Val Loss: 0.1355, Val Acc: 95.60%
# Epoch [990/1000], LR: 0.000010, Train Loss: 0.1258, Train Acc: 96.01%, Val Loss: 0.5364, Val Acc: 84.72%
# Epoch [991/1000], LR: 0.000100, Train Loss: 0.1396, Train Acc: 95.65%, Val Loss: 0.1489, Val Acc: 95.25%
# Epoch [992/1000], LR: 0.000010, Train Loss: 0.1246, Train Acc: 96.05%, Val Loss: 0.1393, Val Acc: 95.75%
# Epoch [993/1000], LR: 0.000010, Train Loss: 0.1258, Train Acc: 96.08%, Val Loss: 0.2017, Val Acc: 93.60%
# Epoch [994/1000], LR: 0.000010, Train Loss: 0.1247, Train Acc: 96.03%, Val Loss: 2.2894, Val Acc: 54.17%
# Epoch [995/1000], LR: 0.001000, Train Loss: 0.1632, Train Acc: 94.88%, Val Loss: 0.1574, Val Acc: 95.24%
# Epoch [996/1000], LR: 0.000010, Train Loss: 0.1368, Train Acc: 95.73%, Val Loss: 0.1259, Val Acc: 96.06%
# Epoch [997/1000], LR: 0.000010, Train Loss: 0.1310, Train Acc: 95.90%, Val Loss: 0.1236, Val Acc: 96.33%
# Epoch [998/1000], LR: 0.000010, Train Loss: 0.1253, Train Acc: 96.07%, Val Loss: 0.1470, Val Acc: 95.19%
# Epoch [999/1000], LR: 0.000010, Train Loss: 0.1253, Train Acc: 96.13%, Val Loss: 0.1610, Val Acc: 94.94%
# Epoch [1000/1000], LR: 0.000010, Train Loss: 0.1288, Train Acc: 96.06%, Val Loss: 0.1421, Val Acc: 95.44%
# Test Accuracy of the best model on the test images: 96.51%
